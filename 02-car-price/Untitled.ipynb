# %%
import numpy as np
import pandas as pd

# %%
data = 'https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/chapter-02-car-price/data.csv'

# %%
df = pd.read_csv('data.csv')

# %%
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
# 2                Luxury,High-Performance      Compact         Coupe
# 3                     Luxury,Performance      Compact         Coupe
# 4                                 Luxury      Compact   Convertible
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350
# 3           28        18        3916  29450
# 4           28        18        3916  34500

# %%
df['Transmission Type']
# Out:
# 0           MANUAL
# 1           MANUAL
# 2           MANUAL
# 3           MANUAL
# 4           MANUAL
#            ...
# 11909    AUTOMATIC
# 11910    AUTOMATIC
# 11911    AUTOMATIC
# 11912    AUTOMATIC
# 11913    AUTOMATIC
# Name: Transmission Type, Length: 11914, dtype: str

# %%
df.count()
# Out:
# Make                 11914
# Model                11914
# Year                 11914
# Engine Fuel Type     11911
# Engine HP            11845
# Engine Cylinders     11884
# Transmission Type    11914
# Driven_Wheels        11914
# Number of Doors      11908
# Market Category       8172
# Vehicle Size         11914
# Vehicle Style        11914
# highway MPG          11914
# city mpg             11914
# Popularity           11914
# MSRP                 11914
# dtype: int64

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')

# %%
df.columns
# Out:
# Index(['make', 'model', 'year', 'engine_fuel_type', 'engine_hp',
#        'engine_cylinders', 'transmission_type', 'driven_wheels',
#        'number_of_doors', 'market_category', 'vehicle_size', 'vehicle_style',
#        'highway_mpg', 'city_mpg', 'popularity', 'msrp'],
#       dtype='str')

# %%
df.columns.values
# Out:
# <StringArray>
# [             'make',             'model',              'year',
#   'engine_fuel_type',         'engine_hp',  'engine_cylinders',
#  'transmission_type',     'driven_wheels',   'number_of_doors',
#    'market_category',      'vehicle_size',     'vehicle_style',
#        'highway_mpg',          'city_mpg',        'popularity',
#               'msrp']
# Length: 16, dtype: str

# %%
df.head()
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          market_category vehicle_size vehicle_style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
# 2                Luxury,High-Performance      Compact         Coupe
# 3                     Luxury,Performance      Compact         Coupe
# 4                                 Luxury      Compact   Convertible
#
#    highway_mpg  city_mpg  popularity   msrp
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350
# 3           28        18        3916  29450
# 4           28        18        3916  34500

# %%
strings = df.dtypes[df.dtypes == 'str'].index
strings
# Out:
# Index(['make', 'model', 'engine_fuel_type', 'transmission_type',
#        'driven_wheels', 'market_category', 'vehicle_size', 'vehicle_style'],
#       dtype='str')

# %%
for col in strings:
    df[col] = df[col].str.lower().str.replace(' ', '_')

# %%
df.head()
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  bmw  1_series_m  2011  premium_unleaded_(required)      335.0
# 1  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 2  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 3  bmw    1_series  2011  premium_unleaded_(required)      230.0
# 4  bmw    1_series  2011  premium_unleaded_(required)      230.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            manual  rear_wheel_drive              2.0
# 1               6.0            manual  rear_wheel_drive              2.0
# 2               6.0            manual  rear_wheel_drive              2.0
# 3               6.0            manual  rear_wheel_drive              2.0
# 4               6.0            manual  rear_wheel_drive              2.0
#
#                          market_category vehicle_size vehicle_style  \
# 0  factory_tuner,luxury,high-performance      compact         coupe
# 1                     luxury,performance      compact   convertible
# 2                luxury,high-performance      compact         coupe
# 3                     luxury,performance      compact         coupe
# 4                                 luxury      compact   convertible
#
#    highway_mpg  city_mpg  popularity   msrp
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350
# 3           28        18        3916  29450
# 4           28        18        3916  34500

# %%
for col in df.columns:
    print(col)
    print(df[col].unique()[:5])
    print(df[col].nunique())
    print()
# Out:
# make
# <StringArray>
# ['bmw', 'audi', 'fiat', 'mercedes-benz', 'chrysler']
# Length: 5, dtype: str
# 48
#
# model
# <StringArray>
# ['1_series_m', '1_series', '100', '124_spider', '190-class']
# Length: 5, dtype: str
# 914
#
# year
# [2011 2012 2013 1992 1993]
# 28
#
# engine_fuel_type
# <StringArray>
# [   'premium_unleaded_(required)',               'regular_unleaded',
#  'premium_unleaded_(recommended)',       'flex-fuel_(unleaded/e85)',
#                          'diesel']
# Length: 5, dtype: str
# 10
#
# engine_hp
# [335. 300. 230. 320. 172.]
# 356
#
# engine_cylinders
# [ 6.  4.  5.  8. 12.]
# 9
#
# transmission_type
# <StringArray>
# ['manual', 'automatic', 'automated_manual', 'direct_drive', 'unknown']
# Length: 5, dtype: str
# 5
#
# driven_wheels
# <StringArray>
# ['rear_wheel_drive', 'front_wheel_drive', 'all_wheel_drive',
#  'four_wheel_drive']
# Length: 4, dtype: str
# 4
#
# number_of_doors
# [ 2.  4.  3. nan]
# 3
#
# market_category
# <StringArray>
# ['factory_tuner,luxury,high-performance',
#                     'luxury,performance',
#                'luxury,high-performance',
#                                 'luxury',
#                            'performance']
# Length: 5, dtype: str
# 71
#
# vehicle_size
# <StringArray>
# ['compact', 'midsize', 'large']
# Length: 3, dtype: str
# 3
#
# vehicle_style
# <StringArray>
# ['coupe', 'convertible', 'sedan', 'wagon', '4dr_hatchback']
# Length: 5, dtype: str
# 16
#
# highway_mpg
# [26 28 27 25 24]
# 59
#
# city_mpg
# [19 20 18 17 16]
# 69
#
# popularity
# [3916 3105  819  617 1013]
# 48
#
# msrp
# [46135 40650 36350 29450 34500]
# 6049

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
sns.histplot(df.msrp[df.msrp < 100000], bins = 50)
# Out:
# <Axes: xlabel='msrp', ylabel='Count'>

# %%
df.head()
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  bmw  1_series_m  2011  premium_unleaded_(required)      335.0
# 1  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 2  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 3  bmw    1_series  2011  premium_unleaded_(required)      230.0
# 4  bmw    1_series  2011  premium_unleaded_(required)      230.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            manual  rear_wheel_drive              2.0
# 1               6.0            manual  rear_wheel_drive              2.0
# 2               6.0            manual  rear_wheel_drive              2.0
# 3               6.0            manual  rear_wheel_drive              2.0
# 4               6.0            manual  rear_wheel_drive              2.0
#
#                          market_category vehicle_size vehicle_style  \
# 0  factory_tuner,luxury,high-performance      compact         coupe
# 1                     luxury,performance      compact   convertible
# 2                luxury,high-performance      compact         coupe
# 3                     luxury,performance      compact         coupe
# 4                                 luxury      compact   convertible
#
#    highway_mpg  city_mpg  popularity   msrp
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350
# 3           28        18        3916  29450
# 4           28        18        3916  34500

# %%
n = int(len(df))
n_val = int(n * 0.2)
n_test = int(n * 0.2)
n_train = n - n_val - n_test

# %%
n_val, n_test, n_train
# Out:
# (2382, 2382, 7150)

# %%
n
# Out:
# 11914

# %%
idx = np.arange(n)

# %%
np.random.shuffle(idx)

# %%
idx
# Out:
# array([11168, 10497,  2853, ...,  8237, 10685,  6433], shape=(11914,))

# %%
df_val = df.iloc[idx[:n_val]]
df_test = df.iloc[idx[n_val:n_val+n_test]]
df_train = df.iloc[idx[n_val+n_test:]]

# %%
df_train
# Out:
#               make                   model  year             engine_fuel_type  \
# 11564        volvo                    xc60  2015             regular_unleaded
# 6719        toyota                  matrix  2012             regular_unleaded
# 9206        toyota                  sienna  2015             regular_unleaded
# 3242      cadillac               cts_wagon  2014             regular_unleaded
# 976        porsche                     911  2017  premium_unleaded_(required)
# ...            ...                     ...   ...                          ...
# 7556   rolls-royce  phantom_drophead_coupe  2014  premium_unleaded_(required)
# 11370      pontiac                    vibe  2010             regular_unleaded
# 8237         dodge              ramcharger  1993             regular_unleaded
# 10685         ford         transit_connect  2017     flex-fuel_(unleaded/e85)
# 6433         buick                 lesabre  2004             regular_unleaded
#
#        engine_hp  engine_cylinders transmission_type      driven_wheels  \
# 11564      302.0               4.0         automatic  front_wheel_drive
# 6719       158.0               4.0         automatic  front_wheel_drive
# 9206       266.0               6.0         automatic  front_wheel_drive
# 3242       318.0               6.0         automatic    all_wheel_drive
# 976        420.0               6.0            manual    all_wheel_drive
# ...          ...               ...               ...                ...
# 7556       453.0              12.0         automatic   rear_wheel_drive
# 11370      158.0               4.0         automatic    all_wheel_drive
# 8237       230.0               8.0         automatic   four_wheel_drive
# 10685      169.0               4.0         automatic  front_wheel_drive
# 6433       205.0               6.0         automatic  front_wheel_drive
#
#        number_of_doors               market_category vehicle_size  \
# 11564              4.0  crossover,luxury,performance      midsize
# 6719               4.0                     hatchback      compact
# 9206               4.0                           NaN        large
# 3242               4.0            luxury,performance      midsize
# 976                2.0       luxury,high-performance      compact
# ...                ...                           ...          ...
# 7556               2.0     exotic,luxury,performance        large
# 11370              4.0                     hatchback      compact
# 8237               2.0                           NaN      midsize
# 10685              4.0                           NaN      compact
# 6433               4.0                           NaN        large
#
#            vehicle_style  highway_mpg  city_mpg  popularity    msrp
# 11564            4dr_suv           30        22         870   41450
# 6719       4dr_hatchback           29        21        2031   20755
# 9206   passenger_minivan           25        18        2031   35200
# 3242               wagon           26        18        1624   51695
# 976          convertible           28        20        1715  122600
# ...                  ...          ...       ...         ...     ...
# 7556         convertible           19        11          86  474600
# 11370      4dr_hatchback           26        20         210   20275
# 8237             2dr_suv           15        11        1851    2000
# 10685      cargo_minivan           27        20        5657   22900
# 6433               sedan           27        18         155   32085
#
# [7150 rows x 16 columns]

# %%
len(df_train), len(df_val), len(df_test)
# Out:
# (7150, 2382, 2382)

# %%
df_train
# Out:
#               make                   model  year             engine_fuel_type  \
# 11564        volvo                    xc60  2015             regular_unleaded
# 6719        toyota                  matrix  2012             regular_unleaded
# 9206        toyota                  sienna  2015             regular_unleaded
# 3242      cadillac               cts_wagon  2014             regular_unleaded
# 976        porsche                     911  2017  premium_unleaded_(required)
# ...            ...                     ...   ...                          ...
# 7556   rolls-royce  phantom_drophead_coupe  2014  premium_unleaded_(required)
# 11370      pontiac                    vibe  2010             regular_unleaded
# 8237         dodge              ramcharger  1993             regular_unleaded
# 10685         ford         transit_connect  2017     flex-fuel_(unleaded/e85)
# 6433         buick                 lesabre  2004             regular_unleaded
#
#        engine_hp  engine_cylinders transmission_type      driven_wheels  \
# 11564      302.0               4.0         automatic  front_wheel_drive
# 6719       158.0               4.0         automatic  front_wheel_drive
# 9206       266.0               6.0         automatic  front_wheel_drive
# 3242       318.0               6.0         automatic    all_wheel_drive
# 976        420.0               6.0            manual    all_wheel_drive
# ...          ...               ...               ...                ...
# 7556       453.0              12.0         automatic   rear_wheel_drive
# 11370      158.0               4.0         automatic    all_wheel_drive
# 8237       230.0               8.0         automatic   four_wheel_drive
# 10685      169.0               4.0         automatic  front_wheel_drive
# 6433       205.0               6.0         automatic  front_wheel_drive
#
#        number_of_doors               market_category vehicle_size  \
# 11564              4.0  crossover,luxury,performance      midsize
# 6719               4.0                     hatchback      compact
# 9206               4.0                           NaN        large
# 3242               4.0            luxury,performance      midsize
# 976                2.0       luxury,high-performance      compact
# ...                ...                           ...          ...
# 7556               2.0     exotic,luxury,performance        large
# 11370              4.0                     hatchback      compact
# 8237               2.0                           NaN      midsize
# 10685              4.0                           NaN      compact
# 6433               4.0                           NaN        large
#
#            vehicle_style  highway_mpg  city_mpg  popularity    msrp
# 11564            4dr_suv           30        22         870   41450
# 6719       4dr_hatchback           29        21        2031   20755
# 9206   passenger_minivan           25        18        2031   35200
# 3242               wagon           26        18        1624   51695
# 976          convertible           28        20        1715  122600
# ...                  ...          ...       ...         ...     ...
# 7556         convertible           19        11          86  474600
# 11370      4dr_hatchback           26        20         210   20275
# 8237             2dr_suv           15        11        1851    2000
# 10685      cargo_minivan           27        20        5657   22900
# 6433               sedan           27        18         155   32085
#
# [7150 rows x 16 columns]

# %%
df_train = df_train.reset_index(drop = True)
df_val = df_val.reset_index(drop = True)
df_test = df_test.reset_index(drop = True)

# %%
df_train
# Out:
#              make                   model  year             engine_fuel_type  \
# 0           volvo                    xc60  2015             regular_unleaded
# 1          toyota                  matrix  2012             regular_unleaded
# 2          toyota                  sienna  2015             regular_unleaded
# 3        cadillac               cts_wagon  2014             regular_unleaded
# 4         porsche                     911  2017  premium_unleaded_(required)
# ...           ...                     ...   ...                          ...
# 7145  rolls-royce  phantom_drophead_coupe  2014  premium_unleaded_(required)
# 7146      pontiac                    vibe  2010             regular_unleaded
# 7147        dodge              ramcharger  1993             regular_unleaded
# 7148         ford         transit_connect  2017     flex-fuel_(unleaded/e85)
# 7149        buick                 lesabre  2004             regular_unleaded
#
#       engine_hp  engine_cylinders transmission_type      driven_wheels  \
# 0         302.0               4.0         automatic  front_wheel_drive
# 1         158.0               4.0         automatic  front_wheel_drive
# 2         266.0               6.0         automatic  front_wheel_drive
# 3         318.0               6.0         automatic    all_wheel_drive
# 4         420.0               6.0            manual    all_wheel_drive
# ...         ...               ...               ...                ...
# 7145      453.0              12.0         automatic   rear_wheel_drive
# 7146      158.0               4.0         automatic    all_wheel_drive
# 7147      230.0               8.0         automatic   four_wheel_drive
# 7148      169.0               4.0         automatic  front_wheel_drive
# 7149      205.0               6.0         automatic  front_wheel_drive
#
#       number_of_doors               market_category vehicle_size  \
# 0                 4.0  crossover,luxury,performance      midsize
# 1                 4.0                     hatchback      compact
# 2                 4.0                           NaN        large
# 3                 4.0            luxury,performance      midsize
# 4                 2.0       luxury,high-performance      compact
# ...               ...                           ...          ...
# 7145              2.0     exotic,luxury,performance        large
# 7146              4.0                     hatchback      compact
# 7147              2.0                           NaN      midsize
# 7148              4.0                           NaN      compact
# 7149              4.0                           NaN        large
#
#           vehicle_style  highway_mpg  city_mpg  popularity    msrp
# 0               4dr_suv           30        22         870   41450
# 1         4dr_hatchback           29        21        2031   20755
# 2     passenger_minivan           25        18        2031   35200
# 3                 wagon           26        18        1624   51695
# 4           convertible           28        20        1715  122600
# ...                 ...          ...       ...         ...     ...
# 7145        convertible           19        11          86  474600
# 7146      4dr_hatchback           26        20         210   20275
# 7147            2dr_suv           15        11        1851    2000
# 7148      cargo_minivan           27        20        5657   22900
# 7149              sedan           27        18         155   32085
#
# [7150 rows x 16 columns]

# %%
y_train = np.log1p(df_train.msrp.values)
y_val = np.log1p(df_val.msrp.values)
y_test = np.log1p(df_test.msrp.values)

# %%
y_train
# Out:
# array([10.63226729,  9.94059064, 10.46882977, ...,  7.60140233,
#        10.03893586, 10.37617508], shape=(7150,))

# %%
del df_train['msrp']

# %%
del df_val['msrp']
del df_test['msrp']

# %%
df_train
# Out:
#              make                   model  year             engine_fuel_type  \
# 0           volvo                    xc60  2015             regular_unleaded
# 1          toyota                  matrix  2012             regular_unleaded
# 2          toyota                  sienna  2015             regular_unleaded
# 3        cadillac               cts_wagon  2014             regular_unleaded
# 4         porsche                     911  2017  premium_unleaded_(required)
# ...           ...                     ...   ...                          ...
# 7145  rolls-royce  phantom_drophead_coupe  2014  premium_unleaded_(required)
# 7146      pontiac                    vibe  2010             regular_unleaded
# 7147        dodge              ramcharger  1993             regular_unleaded
# 7148         ford         transit_connect  2017     flex-fuel_(unleaded/e85)
# 7149        buick                 lesabre  2004             regular_unleaded
#
#       engine_hp  engine_cylinders transmission_type      driven_wheels  \
# 0         302.0               4.0         automatic  front_wheel_drive
# 1         158.0               4.0         automatic  front_wheel_drive
# 2         266.0               6.0         automatic  front_wheel_drive
# 3         318.0               6.0         automatic    all_wheel_drive
# 4         420.0               6.0            manual    all_wheel_drive
# ...         ...               ...               ...                ...
# 7145      453.0              12.0         automatic   rear_wheel_drive
# 7146      158.0               4.0         automatic    all_wheel_drive
# 7147      230.0               8.0         automatic   four_wheel_drive
# 7148      169.0               4.0         automatic  front_wheel_drive
# 7149      205.0               6.0         automatic  front_wheel_drive
#
#       number_of_doors               market_category vehicle_size  \
# 0                 4.0  crossover,luxury,performance      midsize
# 1                 4.0                     hatchback      compact
# 2                 4.0                           NaN        large
# 3                 4.0            luxury,performance      midsize
# 4                 2.0       luxury,high-performance      compact
# ...               ...                           ...          ...
# 7145              2.0     exotic,luxury,performance        large
# 7146              4.0                     hatchback      compact
# 7147              2.0                           NaN      midsize
# 7148              4.0                           NaN      compact
# 7149              4.0                           NaN        large
#
#           vehicle_style  highway_mpg  city_mpg  popularity
# 0               4dr_suv           30        22         870
# 1         4dr_hatchback           29        21        2031
# 2     passenger_minivan           25        18        2031
# 3                 wagon           26        18        1624
# 4           convertible           28        20        1715
# ...                 ...          ...       ...         ...
# 7145        convertible           19        11          86
# 7146      4dr_hatchback           26        20         210
# 7147            2dr_suv           15        11        1851
# 7148      cargo_minivan           27        20        5657
# 7149              sedan           27        18         155
#
# [7150 rows x 15 columns]

# %%
df_train.dtypes
# Out:
# make                     str
# model                    str
# year                   int64
# engine_fuel_type         str
# engine_hp            float64
# engine_cylinders     float64
# transmission_type        str
# driven_wheels            str
# number_of_doors      float64
# market_category          str
# vehicle_size             str
# vehicle_style            str
# highway_mpg            int64
# city_mpg               int64
# popularity             int64
# dtype: object

# %%
base = ['engine_hp', 'engine_cylinders', 'highway_mpg', 'city_mpg', 'popularity']

# %%
base
# Out:
# ['engine_hp', 'engine_cylinders', 'highway_mpg', 'city_mpg', 'popularity']

# %%
df_train[base]
# Out:
#       engine_hp  engine_cylinders  highway_mpg  city_mpg  popularity
# 0         302.0               4.0           30        22         870
# 1         158.0               4.0           29        21        2031
# 2         266.0               6.0           25        18        2031
# 3         318.0               6.0           26        18        1624
# 4         420.0               6.0           28        20        1715
# ...         ...               ...          ...       ...         ...
# 7145      453.0              12.0           19        11          86
# 7146      158.0               4.0           26        20         210
# 7147      230.0               8.0           15        11        1851
# 7148      169.0               4.0           27        20        5657
# 7149      205.0               6.0           27        18         155
#
# [7150 rows x 5 columns]

# %%
X_train = df_train[base].values

# %%
X_train
# Out:
# array([[3.020e+02, 4.000e+00, 3.000e+01, 2.200e+01, 8.700e+02],
#        [1.580e+02, 4.000e+00, 2.900e+01, 2.100e+01, 2.031e+03],
#        [2.660e+02, 6.000e+00, 2.500e+01, 1.800e+01, 2.031e+03],
#        ...,
#        [2.300e+02, 8.000e+00, 1.500e+01, 1.100e+01, 1.851e+03],
#        [1.690e+02, 4.000e+00, 2.700e+01, 2.000e+01, 5.657e+03],
#        [2.050e+02, 6.000e+00, 2.700e+01, 1.800e+01, 1.550e+02]],
#       shape=(7150, 5))

# %%
y_train
# Out:
# array([10.63226729,  9.94059064, 10.46882977, ...,  7.60140233,
#        10.03893586, 10.37617508], shape=(7150,))

# %%
def train_linear_regression(X, y):
    ones = np.ones(X.shape[0])
    X = np.column_stack([ones, X])
    XTX = X.T.dot(X)
    XTX_inv = np.linalg.inv(XTX)
    w_full = XTX_inv.dot(X.T).dot(y)

    return w_full[0], w_full[1:]

# %%
df_train[base].isnull().sum()
# Out:
# engine_hp           46
# engine_cylinders    18
# highway_mpg          0
# city_mpg             0
# popularity           0
# dtype: int64

# %%
X_train = df_train[base].fillna(0).values

# %%
X_train
# Out:
# array([[3.020e+02, 4.000e+00, 3.000e+01, 2.200e+01, 8.700e+02],
#        [1.580e+02, 4.000e+00, 2.900e+01, 2.100e+01, 2.031e+03],
#        [2.660e+02, 6.000e+00, 2.500e+01, 1.800e+01, 2.031e+03],
#        ...,
#        [2.300e+02, 8.000e+00, 1.500e+01, 1.100e+01, 1.851e+03],
#        [1.690e+02, 4.000e+00, 2.700e+01, 2.000e+01, 5.657e+03],
#        [2.050e+02, 6.000e+00, 2.700e+01, 1.800e+01, 1.550e+02]],
#       shape=(7150, 5))

# %%
w0, w = train_linear_regression(X_train, y_train)

# %%
w0
# Out:
# np.float64(7.876483359202509)

# %%
w
# Out:
# array([ 9.58091619e-03, -1.51143360e-01,  1.49820286e-02,  1.61124033e-02,
#        -4.43708495e-06])

# %%
y_pred = w0 + X_train.dot(w)

# %%
sns.histplot(y_pred, color='red', bins = 50, alpha = 0.5)
sns.histplot(y_train, color='blue', bins = 50, alpha = 0.5)
# Out:
# <Axes: ylabel='Count'>

# %%
def rmse(y, y_pred):
    error = (y - y_pred)
    se = error ** 2
    mse = se.mean()
    return np.sqrt(mse)

# %%
rmse(y_train, y_pred)
# Out:
# np.float64(0.7530617164847415)

# %%
def prepare_X(df):
    df = df.copy()
    df['age'] = 2017 - df.year
    features = base + ['age']
    df_num = df[features]
    df_num = df_num.fillna(0)
    X = df_num.values

    return X

# %%
X_train = prepare_X(df_train)

# %%
X_train
# Out:
# array([[3.020e+02, 4.000e+00, 3.000e+01, 2.200e+01, 8.700e+02, 2.000e+00],
#        [1.580e+02, 4.000e+00, 2.900e+01, 2.100e+01, 2.031e+03, 5.000e+00],
#        [2.660e+02, 6.000e+00, 2.500e+01, 1.800e+01, 2.031e+03, 2.000e+00],
#        ...,
#        [2.300e+02, 8.000e+00, 1.500e+01, 1.100e+01, 1.851e+03, 2.400e+01],
#        [1.690e+02, 4.000e+00, 2.700e+01, 2.000e+01, 5.657e+03, 0.000e+00],
#        [2.050e+02, 6.000e+00, 2.700e+01, 1.800e+01, 1.550e+02, 1.300e+01]],
#       shape=(7150, 6))

# %%
df_train.dtypes
# Out:
# make                     str
# model                    str
# year                   int64
# engine_fuel_type         str
# engine_hp            float64
# engine_cylinders     float64
# transmission_type        str
# driven_wheels            str
# number_of_doors      float64
# market_category          str
# vehicle_size             str
# vehicle_style            str
# highway_mpg            int64
# city_mpg               int64
# popularity             int64
# dtype: object

# %%
X_train = prepare_X(df_train)
w0, w = train_linear_regression(X_train, y_train)
X_val = prepare_X(df_val)
y_pred = w0 + X_val.dot(w)

rmse(y_val,y_pred)
# Out:
# np.float64(0.5134726026854786)

# %%
sns.histplot(y_pred, color='red', bins = 50, alpha = 0.5)
sns.histplot(y_val, color='blue', bins = 50, alpha = 0.5)
# Out:
# <Axes: ylabel='Count'>

# %%
df_train.number_of_doors
# Out:
# 0       4.0
# 1       4.0
# 2       4.0
# 3       4.0
# 4       2.0
#        ...
# 7145    2.0
# 7146    4.0
# 7147    2.0
# 7148    4.0
# 7149    4.0
# Name: number_of_doors, Length: 7150, dtype: float64
