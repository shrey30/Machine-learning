# %%
import numpy as np
import pandas as pd

# %%
data = 'https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/chapter-02-car-price/data.csv'

# %%
df = pd.read_csv('data.csv')

# %%
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
# 2                Luxury,High-Performance      Compact         Coupe
# 3                     Luxury,Performance      Compact         Coupe
# 4                                 Luxury      Compact   Convertible
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350
# 3           28        18        3916  29450
# 4           28        18        3916  34500

# %%
df['Transmission Type']
# Out:
# 0           MANUAL
# 1           MANUAL
# 2           MANUAL
# 3           MANUAL
# 4           MANUAL
#            ...
# 11909    AUTOMATIC
# 11910    AUTOMATIC
# 11911    AUTOMATIC
# 11912    AUTOMATIC
# 11913    AUTOMATIC
# Name: Transmission Type, Length: 11914, dtype: str

# %%
df.count()
# Out:
# Make                 11914
# Model                11914
# Year                 11914
# Engine Fuel Type     11911
# Engine HP            11845
# Engine Cylinders     11884
# Transmission Type    11914
# Driven_Wheels        11914
# Number of Doors      11908
# Market Category       8172
# Vehicle Size         11914
# Vehicle Style        11914
# highway MPG          11914
# city mpg             11914
# Popularity           11914
# MSRP                 11914
# dtype: int64

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')

# %%
df.columns
# Out:
# Index(['make', 'model', 'year', 'engine_fuel_type', 'engine_hp',
#        'engine_cylinders', 'transmission_type', 'driven_wheels',
#        'number_of_doors', 'market_category', 'vehicle_size', 'vehicle_style',
#        'highway_mpg', 'city_mpg', 'popularity', 'msrp'],
#       dtype='str')

# %%
df.columns.values
# Out:
# <StringArray>
# [             'make',             'model',              'year',
#   'engine_fuel_type',         'engine_hp',  'engine_cylinders',
#  'transmission_type',     'driven_wheels',   'number_of_doors',
#    'market_category',      'vehicle_size',     'vehicle_style',
#        'highway_mpg',          'city_mpg',        'popularity',
#               'msrp']
# Length: 16, dtype: str

# %%
df.head()
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          market_category vehicle_size vehicle_style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
# 2                Luxury,High-Performance      Compact         Coupe
# 3                     Luxury,Performance      Compact         Coupe
# 4                                 Luxury      Compact   Convertible
#
#    highway_mpg  city_mpg  popularity   msrp
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350
# 3           28        18        3916  29450
# 4           28        18        3916  34500

# %%
strings = df.dtypes[df.dtypes == 'str'].index
strings
# Out:
# Index(['make', 'model', 'engine_fuel_type', 'transmission_type',
#        'driven_wheels', 'market_category', 'vehicle_size', 'vehicle_style'],
#       dtype='str')

# %%
for col in strings:
    df[col] = df[col].str.lower().str.replace(' ', '_')

# %%
df.head()
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  bmw  1_series_m  2011  premium_unleaded_(required)      335.0
# 1  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 2  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 3  bmw    1_series  2011  premium_unleaded_(required)      230.0
# 4  bmw    1_series  2011  premium_unleaded_(required)      230.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            manual  rear_wheel_drive              2.0
# 1               6.0            manual  rear_wheel_drive              2.0
# 2               6.0            manual  rear_wheel_drive              2.0
# 3               6.0            manual  rear_wheel_drive              2.0
# 4               6.0            manual  rear_wheel_drive              2.0
#
#                          market_category vehicle_size vehicle_style  \
# 0  factory_tuner,luxury,high-performance      compact         coupe
# 1                     luxury,performance      compact   convertible
# 2                luxury,high-performance      compact         coupe
# 3                     luxury,performance      compact         coupe
# 4                                 luxury      compact   convertible
#
#    highway_mpg  city_mpg  popularity   msrp
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350
# 3           28        18        3916  29450
# 4           28        18        3916  34500

# %%
for col in df.columns:
    print(col)
    print(df[col].unique()[:5])
    print(df[col].nunique())
    print()
# Out:
# make
# <StringArray>
# ['bmw', 'audi', 'fiat', 'mercedes-benz', 'chrysler']
# Length: 5, dtype: str
# 48
#
# model
# <StringArray>
# ['1_series_m', '1_series', '100', '124_spider', '190-class']
# Length: 5, dtype: str
# 914
#
# year
# [2011 2012 2013 1992 1993]
# 28
#
# engine_fuel_type
# <StringArray>
# [   'premium_unleaded_(required)',               'regular_unleaded',
#  'premium_unleaded_(recommended)',       'flex-fuel_(unleaded/e85)',
#                          'diesel']
# Length: 5, dtype: str
# 10
#
# engine_hp
# [335. 300. 230. 320. 172.]
# 356
#
# engine_cylinders
# [ 6.  4.  5.  8. 12.]
# 9
#
# transmission_type
# <StringArray>
# ['manual', 'automatic', 'automated_manual', 'direct_drive', 'unknown']
# Length: 5, dtype: str
# 5
#
# driven_wheels
# <StringArray>
# ['rear_wheel_drive', 'front_wheel_drive', 'all_wheel_drive',
#  'four_wheel_drive']
# Length: 4, dtype: str
# 4
#
# number_of_doors
# [ 2.  4.  3. nan]
# 3
#
# market_category
# <StringArray>
# ['factory_tuner,luxury,high-performance',
#                     'luxury,performance',
#                'luxury,high-performance',
#                                 'luxury',
#                            'performance']
# Length: 5, dtype: str
# 71
#
# vehicle_size
# <StringArray>
# ['compact', 'midsize', 'large']
# Length: 3, dtype: str
# 3
#
# vehicle_style
# <StringArray>
# ['coupe', 'convertible', 'sedan', 'wagon', '4dr_hatchback']
# Length: 5, dtype: str
# 16
#
# highway_mpg
# [26 28 27 25 24]
# 59
#
# city_mpg
# [19 20 18 17 16]
# 69
#
# popularity
# [3916 3105  819  617 1013]
# 48
#
# msrp
# [46135 40650 36350 29450 34500]
# 6049

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
sns.histplot(df.msrp[df.msrp < 100000], bins = 50)
# Out:
# <Axes: xlabel='msrp', ylabel='Count'>

# %%
df.head()
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  bmw  1_series_m  2011  premium_unleaded_(required)      335.0
# 1  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 2  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 3  bmw    1_series  2011  premium_unleaded_(required)      230.0
# 4  bmw    1_series  2011  premium_unleaded_(required)      230.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            manual  rear_wheel_drive              2.0
# 1               6.0            manual  rear_wheel_drive              2.0
# 2               6.0            manual  rear_wheel_drive              2.0
# 3               6.0            manual  rear_wheel_drive              2.0
# 4               6.0            manual  rear_wheel_drive              2.0
#
#                          market_category vehicle_size vehicle_style  \
# 0  factory_tuner,luxury,high-performance      compact         coupe
# 1                     luxury,performance      compact   convertible
# 2                luxury,high-performance      compact         coupe
# 3                     luxury,performance      compact         coupe
# 4                                 luxury      compact   convertible
#
#    highway_mpg  city_mpg  popularity   msrp
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350
# 3           28        18        3916  29450
# 4           28        18        3916  34500

# %%
n = int(len(df))
n_val = int(n * 0.2)
n_test = int(n * 0.2)
n_train = n - n_val - n_test

# %%
n_val, n_test, n_train
# Out:
# (2382, 2382, 7150)

# %%
n
# Out:
# 11914

# %%
idx = np.arange(n)

# %%
np.random.shuffle(idx)

# %%
idx
# Out:
# array([5650, 9101, 7083, ..., 7210, 1315, 8959], shape=(11914,))

# %%
df_val = df.iloc[idx[:n_val]]
df_test = df.iloc[idx[n_val:n_val+n_test]]
df_train = df.iloc[idx[n_val+n_test:]]

# %%
df_train
# Out:
#                make            model  year             engine_fuel_type  \
# 6588       infiniti              m35  2008  premium_unleaded_(required)
# 1521       cadillac        ats_coupe  2017             regular_unleaded
# 4972         nissan         frontier  2016             regular_unleaded
# 688           mazda              626  2000             regular_unleaded
# 4284        hyundai            excel  1992             regular_unleaded
# ...             ...              ...   ...                          ...
# 1136           audi               a8  2017  premium_unleaded_(required)
# 5310  mercedes-benz  gle-class_coupe  2016  premium_unleaded_(required)
# 7210     volkswagen       new_beetle  2009             regular_unleaded
# 1315         suzuki            aerio  2006             regular_unleaded
# 8959            gmc           safari  2003             regular_unleaded
#
#       engine_hp  engine_cylinders transmission_type      driven_wheels  \
# 6588      275.0               6.0         automatic   rear_wheel_drive
# 1521      335.0               6.0         automatic   rear_wheel_drive
# 4972      261.0               6.0         automatic   four_wheel_drive
# 688       130.0               4.0         automatic  front_wheel_drive
# 4284       81.0               4.0            manual  front_wheel_drive
# ...         ...               ...               ...                ...
# 1136      333.0               6.0         automatic    all_wheel_drive
# 5310      362.0               6.0         automatic    all_wheel_drive
# 7210      150.0               5.0         automatic  front_wheel_drive
# 1315      155.0               4.0         automatic  front_wheel_drive
# 8959      190.0               6.0         automatic   rear_wheel_drive
#
#       number_of_doors               market_category vehicle_size  \
# 6588              4.0            luxury,performance        large
# 1521              2.0       luxury,high-performance      compact
# 4972              4.0                           NaN      compact
# 688               4.0                           NaN      midsize
# 4284              4.0                           NaN      compact
# ...               ...                           ...          ...
# 1136              4.0            luxury,performance        large
# 5310              4.0  crossover,luxury,performance      midsize
# 7210              2.0                     hatchback      compact
# 1315              4.0                           NaN      compact
# 8959              3.0                           NaN        large
#
#           vehicle_style  highway_mpg  city_mpg  popularity   msrp
# 6588              sedan           23        16         190  43900
# 1521              coupe           30        20        1624  46995
# 4972    crew_cab_pickup           21        15        2009  26750
# 688               sedan           25        19         586   2146
# 4284              sedan           33        25        1439   2000
# ...                 ...          ...       ...         ...    ...
# 1136              sedan           29        19        3105  82500
# 5310            4dr_suv           23        17         617  65100
# 7210      2dr_hatchback           29        20         873  19390
# 1315              wagon           28        22         481  15499
# 8959  passenger_minivan           19        14         549  23690
#
# [7150 rows x 16 columns]

# %%
len(df_train), len(df_val), len(df_test)
# Out:
# (7150, 2382, 2382)

# %%
df_train
# Out:
#                make            model  year             engine_fuel_type  \
# 6588       infiniti              m35  2008  premium_unleaded_(required)
# 1521       cadillac        ats_coupe  2017             regular_unleaded
# 4972         nissan         frontier  2016             regular_unleaded
# 688           mazda              626  2000             regular_unleaded
# 4284        hyundai            excel  1992             regular_unleaded
# ...             ...              ...   ...                          ...
# 1136           audi               a8  2017  premium_unleaded_(required)
# 5310  mercedes-benz  gle-class_coupe  2016  premium_unleaded_(required)
# 7210     volkswagen       new_beetle  2009             regular_unleaded
# 1315         suzuki            aerio  2006             regular_unleaded
# 8959            gmc           safari  2003             regular_unleaded
#
#       engine_hp  engine_cylinders transmission_type      driven_wheels  \
# 6588      275.0               6.0         automatic   rear_wheel_drive
# 1521      335.0               6.0         automatic   rear_wheel_drive
# 4972      261.0               6.0         automatic   four_wheel_drive
# 688       130.0               4.0         automatic  front_wheel_drive
# 4284       81.0               4.0            manual  front_wheel_drive
# ...         ...               ...               ...                ...
# 1136      333.0               6.0         automatic    all_wheel_drive
# 5310      362.0               6.0         automatic    all_wheel_drive
# 7210      150.0               5.0         automatic  front_wheel_drive
# 1315      155.0               4.0         automatic  front_wheel_drive
# 8959      190.0               6.0         automatic   rear_wheel_drive
#
#       number_of_doors               market_category vehicle_size  \
# 6588              4.0            luxury,performance        large
# 1521              2.0       luxury,high-performance      compact
# 4972              4.0                           NaN      compact
# 688               4.0                           NaN      midsize
# 4284              4.0                           NaN      compact
# ...               ...                           ...          ...
# 1136              4.0            luxury,performance        large
# 5310              4.0  crossover,luxury,performance      midsize
# 7210              2.0                     hatchback      compact
# 1315              4.0                           NaN      compact
# 8959              3.0                           NaN        large
#
#           vehicle_style  highway_mpg  city_mpg  popularity   msrp
# 6588              sedan           23        16         190  43900
# 1521              coupe           30        20        1624  46995
# 4972    crew_cab_pickup           21        15        2009  26750
# 688               sedan           25        19         586   2146
# 4284              sedan           33        25        1439   2000
# ...                 ...          ...       ...         ...    ...
# 1136              sedan           29        19        3105  82500
# 5310            4dr_suv           23        17         617  65100
# 7210      2dr_hatchback           29        20         873  19390
# 1315              wagon           28        22         481  15499
# 8959  passenger_minivan           19        14         549  23690
#
# [7150 rows x 16 columns]

# %%
df_train = df_train.reset_index(drop = True)
df_val = df_val.reset_index(drop = True)
df_test = df_test.reset_index(drop = True)

# %%
df_train
# Out:
#                make            model  year             engine_fuel_type  \
# 0          infiniti              m35  2008  premium_unleaded_(required)
# 1          cadillac        ats_coupe  2017             regular_unleaded
# 2            nissan         frontier  2016             regular_unleaded
# 3             mazda              626  2000             regular_unleaded
# 4           hyundai            excel  1992             regular_unleaded
# ...             ...              ...   ...                          ...
# 7145           audi               a8  2017  premium_unleaded_(required)
# 7146  mercedes-benz  gle-class_coupe  2016  premium_unleaded_(required)
# 7147     volkswagen       new_beetle  2009             regular_unleaded
# 7148         suzuki            aerio  2006             regular_unleaded
# 7149            gmc           safari  2003             regular_unleaded
#
#       engine_hp  engine_cylinders transmission_type      driven_wheels  \
# 0         275.0               6.0         automatic   rear_wheel_drive
# 1         335.0               6.0         automatic   rear_wheel_drive
# 2         261.0               6.0         automatic   four_wheel_drive
# 3         130.0               4.0         automatic  front_wheel_drive
# 4          81.0               4.0            manual  front_wheel_drive
# ...         ...               ...               ...                ...
# 7145      333.0               6.0         automatic    all_wheel_drive
# 7146      362.0               6.0         automatic    all_wheel_drive
# 7147      150.0               5.0         automatic  front_wheel_drive
# 7148      155.0               4.0         automatic  front_wheel_drive
# 7149      190.0               6.0         automatic   rear_wheel_drive
#
#       number_of_doors               market_category vehicle_size  \
# 0                 4.0            luxury,performance        large
# 1                 2.0       luxury,high-performance      compact
# 2                 4.0                           NaN      compact
# 3                 4.0                           NaN      midsize
# 4                 4.0                           NaN      compact
# ...               ...                           ...          ...
# 7145              4.0            luxury,performance        large
# 7146              4.0  crossover,luxury,performance      midsize
# 7147              2.0                     hatchback      compact
# 7148              4.0                           NaN      compact
# 7149              3.0                           NaN        large
#
#           vehicle_style  highway_mpg  city_mpg  popularity   msrp
# 0                 sedan           23        16         190  43900
# 1                 coupe           30        20        1624  46995
# 2       crew_cab_pickup           21        15        2009  26750
# 3                 sedan           25        19         586   2146
# 4                 sedan           33        25        1439   2000
# ...                 ...          ...       ...         ...    ...
# 7145              sedan           29        19        3105  82500
# 7146            4dr_suv           23        17         617  65100
# 7147      2dr_hatchback           29        20         873  19390
# 7148              wagon           28        22         481  15499
# 7149  passenger_minivan           19        14         549  23690
#
# [7150 rows x 16 columns]

# %%
y_train = np.log1p(df_train.msrp.values)
y_val = np.log1p(df_val.msrp.values)
y_test = np.log1p(df_test.msrp.values)

# %%
y_train
# Out:
# array([10.68969238, 10.75781777, 10.19432713, ...,  9.87256432,
#         9.6485953 , 10.07285051], shape=(7150,))

# %%
del df_train['msrp']

# %%
del df_val['msrp']
del df_test['msrp']

# %%
df_train
# Out:
#                make            model  year             engine_fuel_type  \
# 0          infiniti              m35  2008  premium_unleaded_(required)
# 1          cadillac        ats_coupe  2017             regular_unleaded
# 2            nissan         frontier  2016             regular_unleaded
# 3             mazda              626  2000             regular_unleaded
# 4           hyundai            excel  1992             regular_unleaded
# ...             ...              ...   ...                          ...
# 7145           audi               a8  2017  premium_unleaded_(required)
# 7146  mercedes-benz  gle-class_coupe  2016  premium_unleaded_(required)
# 7147     volkswagen       new_beetle  2009             regular_unleaded
# 7148         suzuki            aerio  2006             regular_unleaded
# 7149            gmc           safari  2003             regular_unleaded
#
#       engine_hp  engine_cylinders transmission_type      driven_wheels  \
# 0         275.0               6.0         automatic   rear_wheel_drive
# 1         335.0               6.0         automatic   rear_wheel_drive
# 2         261.0               6.0         automatic   four_wheel_drive
# 3         130.0               4.0         automatic  front_wheel_drive
# 4          81.0               4.0            manual  front_wheel_drive
# ...         ...               ...               ...                ...
# 7145      333.0               6.0         automatic    all_wheel_drive
# 7146      362.0               6.0         automatic    all_wheel_drive
# 7147      150.0               5.0         automatic  front_wheel_drive
# 7148      155.0               4.0         automatic  front_wheel_drive
# 7149      190.0               6.0         automatic   rear_wheel_drive
#
#       number_of_doors               market_category vehicle_size  \
# 0                 4.0            luxury,performance        large
# 1                 2.0       luxury,high-performance      compact
# 2                 4.0                           NaN      compact
# 3                 4.0                           NaN      midsize
# 4                 4.0                           NaN      compact
# ...               ...                           ...          ...
# 7145              4.0            luxury,performance        large
# 7146              4.0  crossover,luxury,performance      midsize
# 7147              2.0                     hatchback      compact
# 7148              4.0                           NaN      compact
# 7149              3.0                           NaN        large
#
#           vehicle_style  highway_mpg  city_mpg  popularity
# 0                 sedan           23        16         190
# 1                 coupe           30        20        1624
# 2       crew_cab_pickup           21        15        2009
# 3                 sedan           25        19         586
# 4                 sedan           33        25        1439
# ...                 ...          ...       ...         ...
# 7145              sedan           29        19        3105
# 7146            4dr_suv           23        17         617
# 7147      2dr_hatchback           29        20         873
# 7148              wagon           28        22         481
# 7149  passenger_minivan           19        14         549
#
# [7150 rows x 15 columns]

# %%
df_train.dtypes
# Out:
# make                     str
# model                    str
# year                   int64
# engine_fuel_type         str
# engine_hp            float64
# engine_cylinders     float64
# transmission_type        str
# driven_wheels            str
# number_of_doors      float64
# market_category          str
# vehicle_size             str
# vehicle_style            str
# highway_mpg            int64
# city_mpg               int64
# popularity             int64
# dtype: object

# %%
base = ['engine_hp', 'engine_cylinders', 'highway_mpg', 'city_mpg', 'popularity']

# %%
base
# Out:
# ['engine_hp', 'engine_cylinders', 'highway_mpg', 'city_mpg', 'popularity']

# %%
df_train[base]
# Out:
#       engine_hp  engine_cylinders  highway_mpg  city_mpg  popularity
# 0         275.0               6.0           23        16         190
# 1         335.0               6.0           30        20        1624
# 2         261.0               6.0           21        15        2009
# 3         130.0               4.0           25        19         586
# 4          81.0               4.0           33        25        1439
# ...         ...               ...          ...       ...         ...
# 7145      333.0               6.0           29        19        3105
# 7146      362.0               6.0           23        17         617
# 7147      150.0               5.0           29        20         873
# 7148      155.0               4.0           28        22         481
# 7149      190.0               6.0           19        14         549
#
# [7150 rows x 5 columns]

# %%
X_train = df_train[base].values

# %%
X_train
# Out:
# array([[ 275.,    6.,   23.,   16.,  190.],
#        [ 335.,    6.,   30.,   20., 1624.],
#        [ 261.,    6.,   21.,   15., 2009.],
#        ...,
#        [ 150.,    5.,   29.,   20.,  873.],
#        [ 155.,    4.,   28.,   22.,  481.],
#        [ 190.,    6.,   19.,   14.,  549.]], shape=(7150, 5))

# %%
y_train
# Out:
# array([10.68969238, 10.75781777, 10.19432713, ...,  9.87256432,
#         9.6485953 , 10.07285051], shape=(7150,))

# %%
def train_linear_regression(X, y):
    ones = np.ones(X.shape[0])
    X = np.column_stack([ones, X])
    XTX = X.T.dot(X)
    XTX_inv = np.linalg.inv(XTX)
    w_full = XTX_inv.dot(X.T).dot(y)

    return w_full[0], w_full[1:]

# %%
df_train[base].isnull().sum()
# Out:
# engine_hp           39
# engine_cylinders    18
# highway_mpg          0
# city_mpg             0
# popularity           0
# dtype: int64

# %%
X_train = df_train[base].fillna(0).values

# %%
X_train
# Out:
# array([[ 275.,    6.,   23.,   16.,  190.],
#        [ 335.,    6.,   30.,   20., 1624.],
#        [ 261.,    6.,   21.,   15., 2009.],
#        ...,
#        [ 150.,    5.,   29.,   20.,  873.],
#        [ 155.,    4.,   28.,   22.,  481.],
#        [ 190.,    6.,   19.,   14.,  549.]], shape=(7150, 5))

# %%
w0, w = train_linear_regression(X_train, y_train)

# %%
w0
# Out:
# np.float64(7.372489680693097)

# %%
w
# Out:
# array([ 8.94743668e-03, -9.42950849e-02,  4.71175303e-02, -9.05035065e-03,
#        -1.09072765e-05])

# %%
y_pred = w0 + X_train.dot(w)

# %%
sns.histplot(y_pred, color='red', bins = 50, alpha = 0.5)
sns.histplot(y_train, color='blue', bins = 50, alpha = 0.5)
# Out:
# <Axes: ylabel='Count'>

# %%
def rmse(y, y_pred):
    error = (y - y_pred)
    se = error ** 2
    mse = se.mean()
    return np.sqrt(mse)

# %%
rmse(y_train, y_pred)
# Out:
# np.float64(0.7416316734989407)

# %%
def prepare_X(df):
    df = df.copy()
    df['age'] = 2017 - df.year
    features = base + ['age']
    df_num = df[features]
    df_num = df_num.fillna(0)
    X = df_num.values

    return X

# %%
X_train = prepare_X(df_train)

# %%
X_train
# Out:
# array([[2.750e+02, 6.000e+00, 2.300e+01, 1.600e+01, 1.900e+02, 9.000e+00],
#        [3.350e+02, 6.000e+00, 3.000e+01, 2.000e+01, 1.624e+03, 0.000e+00],
#        [2.610e+02, 6.000e+00, 2.100e+01, 1.500e+01, 2.009e+03, 1.000e+00],
#        ...,
#        [1.500e+02, 5.000e+00, 2.900e+01, 2.000e+01, 8.730e+02, 8.000e+00],
#        [1.550e+02, 4.000e+00, 2.800e+01, 2.200e+01, 4.810e+02, 1.100e+01],
#        [1.900e+02, 6.000e+00, 1.900e+01, 1.400e+01, 5.490e+02, 1.400e+01]],
#       shape=(7150, 6))

# %%
df_train.dtypes
# Out:
# make                     str
# model                    str
# year                   int64
# engine_fuel_type         str
# engine_hp            float64
# engine_cylinders     float64
# transmission_type        str
# driven_wheels            str
# number_of_doors      float64
# market_category          str
# vehicle_size             str
# vehicle_style            str
# highway_mpg            int64
# city_mpg               int64
# popularity             int64
# dtype: object

# %%
X_train = prepare_X(df_train)
w0, w = train_linear_regression(X_train, y_train)
X_val = prepare_X(df_val)
y_pred = w0 + X_val.dot(w)

rmse(y_val,y_pred)
# Out:
# np.float64(0.517292282373753)

# %%
sns.histplot(y_pred, color='red', bins = 50, alpha = 0.5)
sns.histplot(y_val, color='blue', bins = 50, alpha = 0.5)
# Out:
# <Axes: ylabel='Count'>

# %%
df_train.number_of_doors
# Out:
# 0       4.0
# 1       2.0
# 2       4.0
# 3       4.0
# 4       4.0
#        ...
# 7145    4.0
# 7146    4.0
# 7147    2.0
# 7148    4.0
# 7149    3.0
# Name: number_of_doors, Length: 7150, dtype: float64

# %%
for v in [2, 3, 4]:
    df_train['door_num_%s' % v] = (df_train.number_of_doors == v).astype('int')

# %%
def prepare_X(df):
    df = df.copy()
    features = base.copy()
    
    df['age'] = 2017 - df.year
    features.append('age')
    
    for v in [2, 3, 4]:
        df['door_num_%s' % v] = (df.number_of_doors == v).astype('int')
        features.append('door_num_%s' % v)
        
    df_num = df[features]
    df_num = df_num.fillna(0)
    X = df_num.values

    return X

# %%
prepare_X(df_train)
# Out:
# array([[275.,   6.,  23., ...,   0.,   0.,   1.],
#        [335.,   6.,  30., ...,   1.,   0.,   0.],
#        [261.,   6.,  21., ...,   0.,   0.,   1.],
#        ...,
#        [150.,   5.,  29., ...,   1.,   0.,   0.],
#        [155.,   4.,  28., ...,   0.,   0.,   1.],
#        [190.,   6.,  19., ...,   0.,   1.,   0.]], shape=(7150, 9))

# %%
X_train = prepare_X(df_train)
w0, w = train_linear_regression(X_train, y_train)
X_val = prepare_X(df_val)
y_pred = w0 + X_val.dot(w)

rmse(y_val,y_pred)
# Out:
# np.float64(0.5164483438902564)

# %%
makes = list(df.make.value_counts().head().index)
makes
# Out:
# ['chevrolet', 'ford', 'volkswagen', 'toyota', 'dodge']

# %%
def prepare_X(df):
    df = df.copy()
    features = base.copy()
    
    df['age'] = 2017 - df.year
    features.append('age')
    
    for v in [2, 3, 4]:
        df['door_num_%s' % v] = (df.number_of_doors == v).astype('int')
        features.append('door_num_%s' % v)

    for v in makes:
        df['make_%s' % v] = (df.make == v).astype('int')
        features.append('make_%s' % v)
        
    df_num = df[features]
    df_num = df_num.fillna(0)
    X = df_num.values

    return X

# %%
X_train = prepare_X(df_train)
w0, w = train_linear_regression(X_train, y_train)
X_val = prepare_X(df_val)
y_pred = w0 + X_val.dot(w)

rmse(y_val,y_pred)
# Out:
# np.float64(0.504828192564658)

# %%
df_train
# Out:
#                make            model  year             engine_fuel_type  \
# 0          infiniti              m35  2008  premium_unleaded_(required)
# 1          cadillac        ats_coupe  2017             regular_unleaded
# 2            nissan         frontier  2016             regular_unleaded
# 3             mazda              626  2000             regular_unleaded
# 4           hyundai            excel  1992             regular_unleaded
# ...             ...              ...   ...                          ...
# 7145           audi               a8  2017  premium_unleaded_(required)
# 7146  mercedes-benz  gle-class_coupe  2016  premium_unleaded_(required)
# 7147     volkswagen       new_beetle  2009             regular_unleaded
# 7148         suzuki            aerio  2006             regular_unleaded
# 7149            gmc           safari  2003             regular_unleaded
#
#       engine_hp  engine_cylinders transmission_type      driven_wheels  \
# 0         275.0               6.0         automatic   rear_wheel_drive
# 1         335.0               6.0         automatic   rear_wheel_drive
# 2         261.0               6.0         automatic   four_wheel_drive
# 3         130.0               4.0         automatic  front_wheel_drive
# 4          81.0               4.0            manual  front_wheel_drive
# ...         ...               ...               ...                ...
# 7145      333.0               6.0         automatic    all_wheel_drive
# 7146      362.0               6.0         automatic    all_wheel_drive
# 7147      150.0               5.0         automatic  front_wheel_drive
# 7148      155.0               4.0         automatic  front_wheel_drive
# 7149      190.0               6.0         automatic   rear_wheel_drive
#
#       number_of_doors               market_category vehicle_size  \
# 0                 4.0            luxury,performance        large
# 1                 2.0       luxury,high-performance      compact
# 2                 4.0                           NaN      compact
# 3                 4.0                           NaN      midsize
# 4                 4.0                           NaN      compact
# ...               ...                           ...          ...
# 7145              4.0            luxury,performance        large
# 7146              4.0  crossover,luxury,performance      midsize
# 7147              2.0                     hatchback      compact
# 7148              4.0                           NaN      compact
# 7149              3.0                           NaN        large
#
#           vehicle_style  highway_mpg  city_mpg  popularity  door_num_2  \
# 0                 sedan           23        16         190           0
# 1                 coupe           30        20        1624           1
# 2       crew_cab_pickup           21        15        2009           0
# 3                 sedan           25        19         586           0
# 4                 sedan           33        25        1439           0
# ...                 ...          ...       ...         ...         ...
# 7145              sedan           29        19        3105           0
# 7146            4dr_suv           23        17         617           0
# 7147      2dr_hatchback           29        20         873           1
# 7148              wagon           28        22         481           0
# 7149  passenger_minivan           19        14         549           0
#
#       door_num_3  door_num_4
# 0              0           1
# 1              0           0
# 2              0           1
# 3              0           1
# 4              0           1
# ...          ...         ...
# 7145           0           1
# 7146           0           1
# 7147           0           0
# 7148           0           1
# 7149           1           0
#
# [7150 rows x 18 columns]

# %%
def train_linear_regression_reg(X, y, r = 0.001):
    
    ones = np.ones(X.shape[0])
    X = np.column_stack([ones, X])
    
    XTX = X.T.dot(X)
    XTX = XTX + r * np.eye(XTX.shape[0])
    
    XTX_inv = np.linalg.inv(XTX)
    w_full = XTX_inv.dot(X.T).dot(y)

    return w_full[0], w_full[1:]

# %%
X_train = prepare_X(df_train)
w0, w = train_linear_regression_reg(X_train, y_train, r = 0.01)
X_val = prepare_X(df_val)
y_pred = w0 + X_val.dot(w)

rmse(y_val,y_pred)
# Out:
# np.float64(0.5048266134096322)

# %%
df_full_train = pd.concat([df_train, df_val]).reset_index(drop = True)

# %%
df_full_train
# Out:
#           make      model  year             engine_fuel_type  engine_hp  \
# 0     infiniti        m35  2008  premium_unleaded_(required)      275.0
# 1     cadillac  ats_coupe  2017             regular_unleaded      335.0
# 2       nissan   frontier  2016             regular_unleaded      261.0
# 3        mazda        626  2000             regular_unleaded      130.0
# 4      hyundai      excel  1992             regular_unleaded       81.0
# ...        ...        ...   ...                          ...        ...
# 9527    nissan       370z  2017  premium_unleaded_(required)      332.0
# 9528     dodge    daytona  1991             regular_unleaded      152.0
# 9529     buick     reatta  1991             regular_unleaded      170.0
# 9530     mazda       cx-9  2015             regular_unleaded      273.0
# 9531     mazda       mx-3  1995             regular_unleaded       88.0
#
#       engine_cylinders transmission_type      driven_wheels  number_of_doors  \
# 0                  6.0         automatic   rear_wheel_drive              4.0
# 1                  6.0         automatic   rear_wheel_drive              2.0
# 2                  6.0         automatic   four_wheel_drive              4.0
# 3                  4.0         automatic  front_wheel_drive              4.0
# 4                  4.0            manual  front_wheel_drive              4.0
# ...                ...               ...                ...              ...
# 9527               6.0            manual   rear_wheel_drive              2.0
# 9528               4.0            manual  front_wheel_drive              2.0
# 9529               6.0         automatic  front_wheel_drive              2.0
# 9530               6.0         automatic  front_wheel_drive              4.0
# 9531               4.0            manual  front_wheel_drive              2.0
#
#                           market_category vehicle_size    vehicle_style  \
# 0                      luxury,performance        large            sedan
# 1                 luxury,high-performance      compact            coupe
# 2                                     NaN      compact  crew_cab_pickup
# 3                                     NaN      midsize            sedan
# 4                                     NaN      compact            sedan
# ...                                   ...          ...              ...
# 9527                     high-performance      compact      convertible
# 9528  hatchback,factory_tuner,performance      compact    2dr_hatchback
# 9529                                  NaN      compact            coupe
# 9530                crossover,performance        large          4dr_suv
# 9531                            hatchback      compact    2dr_hatchback
#
#       highway_mpg  city_mpg  popularity  door_num_2  door_num_3  door_num_4
# 0              23        16         190         0.0         0.0         1.0
# 1              30        20        1624         1.0         0.0         0.0
# 2              21        15        2009         0.0         0.0         1.0
# 3              25        19         586         0.0         0.0         1.0
# 4              33        25        1439         0.0         0.0         1.0
# ...           ...       ...         ...         ...         ...         ...
# 9527           24        17        2009         NaN         NaN         NaN
# 9528           24        18        1851         NaN         NaN         NaN
# 9529           25        16         155         NaN         NaN         NaN
# 9530           24        17         586         NaN         NaN         NaN
# 9531           34        25         586         NaN         NaN         NaN
#
# [9532 rows x 18 columns]

# %%
X_full_train = prepare_X(df_full_train)

# %%
X_full_train
# Out:
# array([[275.,   6.,  23., ...,   0.,   0.,   0.],
#        [335.,   6.,  30., ...,   0.,   0.,   0.],
#        [261.,   6.,  21., ...,   0.,   0.,   0.],
#        ...,
#        [170.,   6.,  25., ...,   0.,   0.,   0.],
#        [273.,   6.,  24., ...,   0.,   0.,   0.],
#        [ 88.,   4.,  34., ...,   0.,   0.,   0.]], shape=(9532, 14))

# %%
y_full_train = np.concatenate([y_train, y_val])

# %%
w0, w = train_linear_regression_reg(X_full_train, y_full_train)

# %%
w0
# Out:
# np.float64(11.33988395695884)

# %%
X_test = prepare_X(df_test)
y_pred = w0 + X_test.dot(w)

rmse(y_test,y_pred)
# Out:
# np.float64(0.5320778434356438)

# %%
car = df_test.iloc[20].to_dict()
car
# Out:
# {'make': 'plymouth',
#  'model': 'laser',
#  'year': 1993,
#  'engine_fuel_type': 'regular_unleaded',
#  'engine_hp': 195.0,
#  'engine_cylinders': 4.0,
#  'transmission_type': 'manual',
#  'driven_wheels': 'front_wheel_drive',
#  'number_of_doors': 2.0,
#  'market_category': 'hatchback,performance',
#  'vehicle_size': 'compact',
#  'vehicle_style': '2dr_hatchback',
#  'highway_mpg': 26,
#  'city_mpg': 19,
#  'popularity': 535}

# %%
df_small = pd.DataFrame([car])

# %%
df_small
# Out:
#        make  model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 0  plymouth  laser  1993  regular_unleaded      195.0               4.0
#
#   transmission_type      driven_wheels  number_of_doors  \
# 0            manual  front_wheel_drive              2.0
#
#          market_category vehicle_size  vehicle_style  highway_mpg  city_mpg  \
# 0  hatchback,performance      compact  2dr_hatchback           26        19
#
#    popularity
# 0         535

# %%
X_small = prepare_X(df_small)

# %%
y_pred = w0 + X_small.dot(w)
y_pred = y_pred[0]
y_pred
# Out:
# np.float64(8.234996518105001)

# %%
np.expm1(y_pred)
# Out:
# np.float64(3769.6267680840897)

# %%
np.expm1(y_test[20])
# Out:
# np.float64(2000.0)
