# %%
import numpy as np
import pandas as pd

# %%
data = 'https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/chapter-02-car-price/data.csv'

# %%
df = pd.read_csv('data.csv')

# %%
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
# 2                Luxury,High-Performance      Compact         Coupe
# 3                     Luxury,Performance      Compact         Coupe
# 4                                 Luxury      Compact   Convertible
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350
# 3           28        18        3916  29450
# 4           28        18        3916  34500

# %%
df['Transmission Type']
# Out:
# 0           MANUAL
# 1           MANUAL
# 2           MANUAL
# 3           MANUAL
# 4           MANUAL
#            ...
# 11909    AUTOMATIC
# 11910    AUTOMATIC
# 11911    AUTOMATIC
# 11912    AUTOMATIC
# 11913    AUTOMATIC
# Name: Transmission Type, Length: 11914, dtype: str

# %%
df.count()
# Out:
# Make                 11914
# Model                11914
# Year                 11914
# Engine Fuel Type     11911
# Engine HP            11845
# Engine Cylinders     11884
# Transmission Type    11914
# Driven_Wheels        11914
# Number of Doors      11908
# Market Category       8172
# Vehicle Size         11914
# Vehicle Style        11914
# highway MPG          11914
# city mpg             11914
# Popularity           11914
# MSRP                 11914
# dtype: int64

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')

# %%
df.columns
# Out:
# Index(['make', 'model', 'year', 'engine_fuel_type', 'engine_hp',
#        'engine_cylinders', 'transmission_type', 'driven_wheels',
#        'number_of_doors', 'market_category', 'vehicle_size', 'vehicle_style',
#        'highway_mpg', 'city_mpg', 'popularity', 'msrp'],
#       dtype='str')

# %%
df.columns.values
# Out:
# <StringArray>
# [             'make',             'model',              'year',
#   'engine_fuel_type',         'engine_hp',  'engine_cylinders',
#  'transmission_type',     'driven_wheels',   'number_of_doors',
#    'market_category',      'vehicle_size',     'vehicle_style',
#        'highway_mpg',          'city_mpg',        'popularity',
#               'msrp']
# Length: 16, dtype: str

# %%
df.head()
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          market_category vehicle_size vehicle_style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
# 2                Luxury,High-Performance      Compact         Coupe
# 3                     Luxury,Performance      Compact         Coupe
# 4                                 Luxury      Compact   Convertible
#
#    highway_mpg  city_mpg  popularity   msrp
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350
# 3           28        18        3916  29450
# 4           28        18        3916  34500

# %%
strings = df.dtypes[df.dtypes == 'str'].index
strings
# Out:
# Index(['make', 'model', 'engine_fuel_type', 'transmission_type',
#        'driven_wheels', 'market_category', 'vehicle_size', 'vehicle_style'],
#       dtype='str')

# %%
for col in strings:
    df[col] = df[col].str.lower().str.replace(' ', '_')

# %%
df.head()
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  bmw  1_series_m  2011  premium_unleaded_(required)      335.0
# 1  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 2  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 3  bmw    1_series  2011  premium_unleaded_(required)      230.0
# 4  bmw    1_series  2011  premium_unleaded_(required)      230.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            manual  rear_wheel_drive              2.0
# 1               6.0            manual  rear_wheel_drive              2.0
# 2               6.0            manual  rear_wheel_drive              2.0
# 3               6.0            manual  rear_wheel_drive              2.0
# 4               6.0            manual  rear_wheel_drive              2.0
#
#                          market_category vehicle_size vehicle_style  \
# 0  factory_tuner,luxury,high-performance      compact         coupe
# 1                     luxury,performance      compact   convertible
# 2                luxury,high-performance      compact         coupe
# 3                     luxury,performance      compact         coupe
# 4                                 luxury      compact   convertible
#
#    highway_mpg  city_mpg  popularity   msrp
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350
# 3           28        18        3916  29450
# 4           28        18        3916  34500

# %%
for col in df.columns:
    print(col)
    print(df[col].unique()[:5])
    print(df[col].nunique())
    print()
# Out:
# make
# <StringArray>
# ['bmw', 'audi', 'fiat', 'mercedes-benz', 'chrysler']
# Length: 5, dtype: str
# 48
#
# model
# <StringArray>
# ['1_series_m', '1_series', '100', '124_spider', '190-class']
# Length: 5, dtype: str
# 914
#
# year
# [2011 2012 2013 1992 1993]
# 28
#
# engine_fuel_type
# <StringArray>
# [   'premium_unleaded_(required)',               'regular_unleaded',
#  'premium_unleaded_(recommended)',       'flex-fuel_(unleaded/e85)',
#                          'diesel']
# Length: 5, dtype: str
# 10
#
# engine_hp
# [335. 300. 230. 320. 172.]
# 356
#
# engine_cylinders
# [ 6.  4.  5.  8. 12.]
# 9
#
# transmission_type
# <StringArray>
# ['manual', 'automatic', 'automated_manual', 'direct_drive', 'unknown']
# Length: 5, dtype: str
# 5
#
# driven_wheels
# <StringArray>
# ['rear_wheel_drive', 'front_wheel_drive', 'all_wheel_drive',
#  'four_wheel_drive']
# Length: 4, dtype: str
# 4
#
# number_of_doors
# [ 2.  4.  3. nan]
# 3
#
# market_category
# <StringArray>
# ['factory_tuner,luxury,high-performance',
#                     'luxury,performance',
#                'luxury,high-performance',
#                                 'luxury',
#                            'performance']
# Length: 5, dtype: str
# 71
#
# vehicle_size
# <StringArray>
# ['compact', 'midsize', 'large']
# Length: 3, dtype: str
# 3
#
# vehicle_style
# <StringArray>
# ['coupe', 'convertible', 'sedan', 'wagon', '4dr_hatchback']
# Length: 5, dtype: str
# 16
#
# highway_mpg
# [26 28 27 25 24]
# 59
#
# city_mpg
# [19 20 18 17 16]
# 69
#
# popularity
# [3916 3105  819  617 1013]
# 48
#
# msrp
# [46135 40650 36350 29450 34500]
# 6049

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
sns.histplot(df.msrp[df.msrp < 100000], bins = 50)
# Out:
# <Axes: xlabel='msrp', ylabel='Count'>

# %%
df.head()
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  bmw  1_series_m  2011  premium_unleaded_(required)      335.0
# 1  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 2  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 3  bmw    1_series  2011  premium_unleaded_(required)      230.0
# 4  bmw    1_series  2011  premium_unleaded_(required)      230.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            manual  rear_wheel_drive              2.0
# 1               6.0            manual  rear_wheel_drive              2.0
# 2               6.0            manual  rear_wheel_drive              2.0
# 3               6.0            manual  rear_wheel_drive              2.0
# 4               6.0            manual  rear_wheel_drive              2.0
#
#                          market_category vehicle_size vehicle_style  \
# 0  factory_tuner,luxury,high-performance      compact         coupe
# 1                     luxury,performance      compact   convertible
# 2                luxury,high-performance      compact         coupe
# 3                     luxury,performance      compact         coupe
# 4                                 luxury      compact   convertible
#
#    highway_mpg  city_mpg  popularity   msrp
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350
# 3           28        18        3916  29450
# 4           28        18        3916  34500

# %%
n = int(len(df))
n_val = int(n * 0.2)
n_test = int(n * 0.2)
n_train = n - n_val - n_test

# %%
n_val, n_test, n_train
# Out:
# (2382, 2382, 7150)

# %%
n
# Out:
# 11914

# %%
idx = np.arange(n)

# %%
np.random.shuffle(idx)

# %%
idx
# Out:
# array([ 4365,  6167,  5286, ...,  3341, 11847,  9268], shape=(11914,))

# %%
df_val = df.iloc[idx[:n_val]]
df_test = df.iloc[idx[n_val:n_val+n_test]]
df_train = df.iloc[idx[n_val+n_test:]]

# %%
df_train
# Out:
#               make                model  year                engine_fuel_type  \
# 6939         dodge               monaco  1990                regular_unleaded
# 11891          bmw                 z4_m  2007     premium_unleaded_(required)
# 7385    mitsubishi            outlander  2016                regular_unleaded
# 7884          audi                   q7  2015                          diesel
# 1491      cadillac            ats_coupe  2015  premium_unleaded_(recommended)
# ...            ...                  ...   ...                             ...
# 4034        suzuki              equator  2010                regular_unleaded
# 3565   lamborghini               diablo  2001     premium_unleaded_(required)
# 3341         mazda                 cx-3  2016                regular_unleaded
# 11847          gmc             yukon_xl  2015        flex-fuel_(unleaded/e85)
# 9268           gmc  sierra_1500_classic  2007        flex-fuel_(unleaded/e85)
#
#        engine_hp  engine_cylinders transmission_type      driven_wheels  \
# 6939       150.0               6.0         automatic  front_wheel_drive
# 11891      330.0               6.0            manual   rear_wheel_drive
# 7385       166.0               4.0         automatic    all_wheel_drive
# 7884       240.0               6.0         automatic    all_wheel_drive
# 1491       272.0               4.0         automatic    all_wheel_drive
# ...          ...               ...               ...                ...
# 4034       261.0               6.0         automatic   rear_wheel_drive
# 3565       550.0              12.0            manual    all_wheel_drive
# 3341       146.0               4.0         automatic    all_wheel_drive
# 11847      355.0               8.0         automatic   four_wheel_drive
# 9268       295.0               8.0         automatic   rear_wheel_drive
#
#        number_of_doors                        market_category vehicle_size  \
# 6939               4.0                                    NaN      midsize
# 11891              2.0  factory_tuner,luxury,high-performance      compact
# 7385               4.0                              crossover      midsize
# 7884               4.0                crossover,luxury,diesel        large
# 1491               2.0                     luxury,performance      compact
# ...                ...                                    ...          ...
# 4034               4.0                                    NaN      compact
# 3565               2.0                exotic,high-performance      compact
# 3341               4.0                              crossover      compact
# 11847              4.0                              flex_fuel        large
# 9268               4.0                              flex_fuel        large
#
#          vehicle_style  highway_mpg  city_mpg  popularity    msrp
# 6939             sedan           24        15        1851    2000
# 11891      convertible           22        15        3916   52100
# 7385           4dr_suv           31        25         436   24995
# 7884           4dr_suv           28        19        3105   65400
# 1491             coupe           29        20        1624   40445
# ...                ...          ...       ...         ...     ...
# 4034   crew_cab_pickup           20        15         481   24775
# 3565             coupe           12         9        1158  294900
# 3341           4dr_suv           32        27         586   26240
# 11847          4dr_suv           22        15         549   53440
# 9268   crew_cab_pickup           19        14         549   32690
#
# [7150 rows x 16 columns]

# %%
len(df_train), len(df_val), len(df_test)
# Out:
# (7150, 2382, 2382)

# %%
df_train
# Out:
#               make                model  year                engine_fuel_type  \
# 6939         dodge               monaco  1990                regular_unleaded
# 11891          bmw                 z4_m  2007     premium_unleaded_(required)
# 7385    mitsubishi            outlander  2016                regular_unleaded
# 7884          audi                   q7  2015                          diesel
# 1491      cadillac            ats_coupe  2015  premium_unleaded_(recommended)
# ...            ...                  ...   ...                             ...
# 4034        suzuki              equator  2010                regular_unleaded
# 3565   lamborghini               diablo  2001     premium_unleaded_(required)
# 3341         mazda                 cx-3  2016                regular_unleaded
# 11847          gmc             yukon_xl  2015        flex-fuel_(unleaded/e85)
# 9268           gmc  sierra_1500_classic  2007        flex-fuel_(unleaded/e85)
#
#        engine_hp  engine_cylinders transmission_type      driven_wheels  \
# 6939       150.0               6.0         automatic  front_wheel_drive
# 11891      330.0               6.0            manual   rear_wheel_drive
# 7385       166.0               4.0         automatic    all_wheel_drive
# 7884       240.0               6.0         automatic    all_wheel_drive
# 1491       272.0               4.0         automatic    all_wheel_drive
# ...          ...               ...               ...                ...
# 4034       261.0               6.0         automatic   rear_wheel_drive
# 3565       550.0              12.0            manual    all_wheel_drive
# 3341       146.0               4.0         automatic    all_wheel_drive
# 11847      355.0               8.0         automatic   four_wheel_drive
# 9268       295.0               8.0         automatic   rear_wheel_drive
#
#        number_of_doors                        market_category vehicle_size  \
# 6939               4.0                                    NaN      midsize
# 11891              2.0  factory_tuner,luxury,high-performance      compact
# 7385               4.0                              crossover      midsize
# 7884               4.0                crossover,luxury,diesel        large
# 1491               2.0                     luxury,performance      compact
# ...                ...                                    ...          ...
# 4034               4.0                                    NaN      compact
# 3565               2.0                exotic,high-performance      compact
# 3341               4.0                              crossover      compact
# 11847              4.0                              flex_fuel        large
# 9268               4.0                              flex_fuel        large
#
#          vehicle_style  highway_mpg  city_mpg  popularity    msrp
# 6939             sedan           24        15        1851    2000
# 11891      convertible           22        15        3916   52100
# 7385           4dr_suv           31        25         436   24995
# 7884           4dr_suv           28        19        3105   65400
# 1491             coupe           29        20        1624   40445
# ...                ...          ...       ...         ...     ...
# 4034   crew_cab_pickup           20        15         481   24775
# 3565             coupe           12         9        1158  294900
# 3341           4dr_suv           32        27         586   26240
# 11847          4dr_suv           22        15         549   53440
# 9268   crew_cab_pickup           19        14         549   32690
#
# [7150 rows x 16 columns]

# %%
df_train = df_train.reset_index(drop = True)
df_val = df_val.reset_index(drop = True)
df_test = df_test.reset_index(drop = True)

# %%
df_train
# Out:
#              make                model  year                engine_fuel_type  \
# 0           dodge               monaco  1990                regular_unleaded
# 1             bmw                 z4_m  2007     premium_unleaded_(required)
# 2      mitsubishi            outlander  2016                regular_unleaded
# 3            audi                   q7  2015                          diesel
# 4        cadillac            ats_coupe  2015  premium_unleaded_(recommended)
# ...           ...                  ...   ...                             ...
# 7145       suzuki              equator  2010                regular_unleaded
# 7146  lamborghini               diablo  2001     premium_unleaded_(required)
# 7147        mazda                 cx-3  2016                regular_unleaded
# 7148          gmc             yukon_xl  2015        flex-fuel_(unleaded/e85)
# 7149          gmc  sierra_1500_classic  2007        flex-fuel_(unleaded/e85)
#
#       engine_hp  engine_cylinders transmission_type      driven_wheels  \
# 0         150.0               6.0         automatic  front_wheel_drive
# 1         330.0               6.0            manual   rear_wheel_drive
# 2         166.0               4.0         automatic    all_wheel_drive
# 3         240.0               6.0         automatic    all_wheel_drive
# 4         272.0               4.0         automatic    all_wheel_drive
# ...         ...               ...               ...                ...
# 7145      261.0               6.0         automatic   rear_wheel_drive
# 7146      550.0              12.0            manual    all_wheel_drive
# 7147      146.0               4.0         automatic    all_wheel_drive
# 7148      355.0               8.0         automatic   four_wheel_drive
# 7149      295.0               8.0         automatic   rear_wheel_drive
#
#       number_of_doors                        market_category vehicle_size  \
# 0                 4.0                                    NaN      midsize
# 1                 2.0  factory_tuner,luxury,high-performance      compact
# 2                 4.0                              crossover      midsize
# 3                 4.0                crossover,luxury,diesel        large
# 4                 2.0                     luxury,performance      compact
# ...               ...                                    ...          ...
# 7145              4.0                                    NaN      compact
# 7146              2.0                exotic,high-performance      compact
# 7147              4.0                              crossover      compact
# 7148              4.0                              flex_fuel        large
# 7149              4.0                              flex_fuel        large
#
#         vehicle_style  highway_mpg  city_mpg  popularity    msrp
# 0               sedan           24        15        1851    2000
# 1         convertible           22        15        3916   52100
# 2             4dr_suv           31        25         436   24995
# 3             4dr_suv           28        19        3105   65400
# 4               coupe           29        20        1624   40445
# ...               ...          ...       ...         ...     ...
# 7145  crew_cab_pickup           20        15         481   24775
# 7146            coupe           12         9        1158  294900
# 7147          4dr_suv           32        27         586   26240
# 7148          4dr_suv           22        15         549   53440
# 7149  crew_cab_pickup           19        14         549   32690
#
# [7150 rows x 16 columns]

# %%
y_train = np.log1p(df_train.msrp.values)
y_val = np.log1p(df_val.msrp.values)
y_test = np.log1p(df_test.msrp.values)

# %%
y_train
# Out:
# array([ 7.60140233, 10.86093942, 10.12647109, ..., 10.17507835,
#        10.88633352, 10.39485509], shape=(7150,))

# %%
del df_train['msrp']

# %%
del df_val['msrp']
del df_test['msrp']

# %%
df_train
# Out:
#              make                model  year                engine_fuel_type  \
# 0           dodge               monaco  1990                regular_unleaded
# 1             bmw                 z4_m  2007     premium_unleaded_(required)
# 2      mitsubishi            outlander  2016                regular_unleaded
# 3            audi                   q7  2015                          diesel
# 4        cadillac            ats_coupe  2015  premium_unleaded_(recommended)
# ...           ...                  ...   ...                             ...
# 7145       suzuki              equator  2010                regular_unleaded
# 7146  lamborghini               diablo  2001     premium_unleaded_(required)
# 7147        mazda                 cx-3  2016                regular_unleaded
# 7148          gmc             yukon_xl  2015        flex-fuel_(unleaded/e85)
# 7149          gmc  sierra_1500_classic  2007        flex-fuel_(unleaded/e85)
#
#       engine_hp  engine_cylinders transmission_type      driven_wheels  \
# 0         150.0               6.0         automatic  front_wheel_drive
# 1         330.0               6.0            manual   rear_wheel_drive
# 2         166.0               4.0         automatic    all_wheel_drive
# 3         240.0               6.0         automatic    all_wheel_drive
# 4         272.0               4.0         automatic    all_wheel_drive
# ...         ...               ...               ...                ...
# 7145      261.0               6.0         automatic   rear_wheel_drive
# 7146      550.0              12.0            manual    all_wheel_drive
# 7147      146.0               4.0         automatic    all_wheel_drive
# 7148      355.0               8.0         automatic   four_wheel_drive
# 7149      295.0               8.0         automatic   rear_wheel_drive
#
#       number_of_doors                        market_category vehicle_size  \
# 0                 4.0                                    NaN      midsize
# 1                 2.0  factory_tuner,luxury,high-performance      compact
# 2                 4.0                              crossover      midsize
# 3                 4.0                crossover,luxury,diesel        large
# 4                 2.0                     luxury,performance      compact
# ...               ...                                    ...          ...
# 7145              4.0                                    NaN      compact
# 7146              2.0                exotic,high-performance      compact
# 7147              4.0                              crossover      compact
# 7148              4.0                              flex_fuel        large
# 7149              4.0                              flex_fuel        large
#
#         vehicle_style  highway_mpg  city_mpg  popularity
# 0               sedan           24        15        1851
# 1         convertible           22        15        3916
# 2             4dr_suv           31        25         436
# 3             4dr_suv           28        19        3105
# 4               coupe           29        20        1624
# ...               ...          ...       ...         ...
# 7145  crew_cab_pickup           20        15         481
# 7146            coupe           12         9        1158
# 7147          4dr_suv           32        27         586
# 7148          4dr_suv           22        15         549
# 7149  crew_cab_pickup           19        14         549
#
# [7150 rows x 15 columns]

# %%
df_train.dtypes
# Out:
# make                     str
# model                    str
# year                   int64
# engine_fuel_type         str
# engine_hp            float64
# engine_cylinders     float64
# transmission_type        str
# driven_wheels            str
# number_of_doors      float64
# market_category          str
# vehicle_size             str
# vehicle_style            str
# highway_mpg            int64
# city_mpg               int64
# popularity             int64
# dtype: object

# %%
base = ['engine_hp', 'engine_cylinders', 'highway_mpg', 'city_mpg', 'popularity']

# %%
base
# Out:
# ['engine_hp', 'engine_cylinders', 'highway_mpg', 'city_mpg', 'popularity']

# %%
df_train[base]
# Out:
#       engine_hp  engine_cylinders  highway_mpg  city_mpg  popularity
# 0         150.0               6.0           24        15        1851
# 1         330.0               6.0           22        15        3916
# 2         166.0               4.0           31        25         436
# 3         240.0               6.0           28        19        3105
# 4         272.0               4.0           29        20        1624
# ...         ...               ...          ...       ...         ...
# 7145      261.0               6.0           20        15         481
# 7146      550.0              12.0           12         9        1158
# 7147      146.0               4.0           32        27         586
# 7148      355.0               8.0           22        15         549
# 7149      295.0               8.0           19        14         549
#
# [7150 rows x 5 columns]

# %%
X_train = df_train[base].values

# %%
X_train
# Out:
# array([[ 150.,    6.,   24.,   15., 1851.],
#        [ 330.,    6.,   22.,   15., 3916.],
#        [ 166.,    4.,   31.,   25.,  436.],
#        ...,
#        [ 146.,    4.,   32.,   27.,  586.],
#        [ 355.,    8.,   22.,   15.,  549.],
#        [ 295.,    8.,   19.,   14.,  549.]], shape=(7150, 5))

# %%
y_train
# Out:
# array([ 7.60140233, 10.86093942, 10.12647109, ..., 10.17507835,
#        10.88633352, 10.39485509], shape=(7150,))

# %%
def train_linear_regression(X, y):
    ones = np.ones(X.shape[0])
    X = np.column_stack([ones, X])
    XTX = X.T.dot(X)
    XTX_inv = np.linalg.inv(XTX)
    w_full = XTX_inv.dot(X.T).dot(y)

    return w_full[0], w_full[1:]

# %%
df_train[base].isnull().sum()
# Out:
# engine_hp           48
# engine_cylinders    18
# highway_mpg          0
# city_mpg             0
# popularity           0
# dtype: int64

# %%
X_train = df_train[base].fillna(0).values

# %%
X_train
# Out:
# array([[ 150.,    6.,   24.,   15., 1851.],
#        [ 330.,    6.,   22.,   15., 3916.],
#        [ 166.,    4.,   31.,   25.,  436.],
#        ...,
#        [ 146.,    4.,   32.,   27.,  586.],
#        [ 355.,    8.,   22.,   15.,  549.],
#        [ 295.,    8.,   19.,   14.,  549.]], shape=(7150, 5))

# %%
w0, w = train_linear_regression(X_train, y_train)

# %%
w0
# Out:
# np.float64(7.457121229753587)

# %%
w
# Out:
# array([ 9.10490827e-03, -1.08921488e-01,  4.86835982e-02, -1.36931000e-02,
#        -8.61588036e-06])

# %%
y_pred = w0 + X_train.dot(w)

# %%
sns.histplot(y_pred, color='red', bins = 50, alpha = 0.5)
sns.histplot(y_train, color='blue', bins = 50, alpha = 0.5)
# Out:
# <Axes: ylabel='Count'>

# %%
def rmse(y, y_pred):
    error = (y - y_pred)
    se = error ** 2
    mse = se.mean()
    return np.sqrt(mse)

# %%
rmse(y_train, y_pred)
# Out:
# np.float64(0.7482284313804021)

# %%
def prepare_X(df):
    df = df.copy()
    df['age'] = 2017 - df.year
    features = base + ['age']
    df_num = df[features]
    df_num = df_num.fillna(0)
    X = df_num.values

    return X

# %%
X_train = prepare_X(df_train)

# %%
X_train
# Out:
# array([[1.500e+02, 6.000e+00, 2.400e+01, 1.500e+01, 1.851e+03, 2.700e+01],
#        [3.300e+02, 6.000e+00, 2.200e+01, 1.500e+01, 3.916e+03, 1.000e+01],
#        [1.660e+02, 4.000e+00, 3.100e+01, 2.500e+01, 4.360e+02, 1.000e+00],
#        ...,
#        [1.460e+02, 4.000e+00, 3.200e+01, 2.700e+01, 5.860e+02, 1.000e+00],
#        [3.550e+02, 8.000e+00, 2.200e+01, 1.500e+01, 5.490e+02, 2.000e+00],
#        [2.950e+02, 8.000e+00, 1.900e+01, 1.400e+01, 5.490e+02, 1.000e+01]],
#       shape=(7150, 6))

# %%
df_train.dtypes
# Out:
# make                     str
# model                    str
# year                   int64
# engine_fuel_type         str
# engine_hp            float64
# engine_cylinders     float64
# transmission_type        str
# driven_wheels            str
# number_of_doors      float64
# market_category          str
# vehicle_size             str
# vehicle_style            str
# highway_mpg            int64
# city_mpg               int64
# popularity             int64
# dtype: object

# %%
X_train = prepare_X(df_train)
w0, w = train_linear_regression(X_train, y_train)
X_val = prepare_X(df_val)
y_pred = w0 + X_val.dot(w)

rmse(y_val,y_pred)
# Out:
# np.float64(0.532775677293495)

# %%
sns.histplot(y_pred, color='red', bins = 50, alpha = 0.5)
sns.histplot(y_val, color='blue', bins = 50, alpha = 0.5)
# Out:
# <Axes: ylabel='Count'>

# %%
df_train.number_of_doors
# Out:
# 0       4.0
# 1       2.0
# 2       4.0
# 3       4.0
# 4       2.0
#        ...
# 7145    4.0
# 7146    2.0
# 7147    4.0
# 7148    4.0
# 7149    4.0
# Name: number_of_doors, Length: 7150, dtype: float64

# %%
for v in [2, 3, 4]:
    df_train['door_num_%s' % v] = (df_train.number_of_doors == v).astype('int')

# %%
def prepare_X(df):
    df = df.copy()
    features = base.copy()
    
    df['age'] = 2017 - df.year
    features.append('age')
    
    for v in [2, 3, 4]:
        df['door_num_%s' % v] = (df.number_of_doors == v).astype('int')
        features.append('door_num_%s' % v)
        
    df_num = df[features]
    df_num = df_num.fillna(0)
    X = df_num.values

    return X

# %%
prepare_X(df_train)
# Out:
# array([[150.,   6.,  24., ...,   0.,   0.,   1.],
#        [330.,   6.,  22., ...,   1.,   0.,   0.],
#        [166.,   4.,  31., ...,   0.,   0.,   1.],
#        ...,
#        [146.,   4.,  32., ...,   0.,   0.,   1.],
#        [355.,   8.,  22., ...,   0.,   0.,   1.],
#        [295.,   8.,  19., ...,   0.,   0.,   1.]], shape=(7150, 9))

# %%
X_train = prepare_X(df_train)
w0, w = train_linear_regression(X_train, y_train)
X_val = prepare_X(df_val)
y_pred = w0 + X_val.dot(w)

rmse(y_val,y_pred)
# Out:
# np.float64(0.5355349503703641)

# %%
makes = list(df.make.value_counts().head().index)
makes
# Out:
# ['chevrolet', 'ford', 'volkswagen', 'toyota', 'dodge']

# %%
def prepare_X(df):
    df = df.copy()
    features = base.copy()
    
    df['age'] = 2017 - df.year
    features.append('age')
    
    for v in [2, 3, 4]:
        df['door_num_%s' % v] = (df.number_of_doors == v).astype('int')
        features.append('door_num_%s' % v)

    for v in makes:
        df['make_%s' % v] = (df.make == v).astype('int')
        features.append('make_%s' % v)
        
    df_num = df[features]
    df_num = df_num.fillna(0)
    X = df_num.values

    return X

# %%
X_train = prepare_X(df_train)
w0, w = train_linear_regression(X_train, y_train)
X_val = prepare_X(df_val)
y_pred = w0 + X_val.dot(w)

rmse(y_val,y_pred)
# Out:
# np.float64(0.5383566878222237)

# %%
df_train
# Out:
#              make                model  year                engine_fuel_type  \
# 0           dodge               monaco  1990                regular_unleaded
# 1             bmw                 z4_m  2007     premium_unleaded_(required)
# 2      mitsubishi            outlander  2016                regular_unleaded
# 3            audi                   q7  2015                          diesel
# 4        cadillac            ats_coupe  2015  premium_unleaded_(recommended)
# ...           ...                  ...   ...                             ...
# 7145       suzuki              equator  2010                regular_unleaded
# 7146  lamborghini               diablo  2001     premium_unleaded_(required)
# 7147        mazda                 cx-3  2016                regular_unleaded
# 7148          gmc             yukon_xl  2015        flex-fuel_(unleaded/e85)
# 7149          gmc  sierra_1500_classic  2007        flex-fuel_(unleaded/e85)
#
#       engine_hp  engine_cylinders transmission_type      driven_wheels  \
# 0         150.0               6.0         automatic  front_wheel_drive
# 1         330.0               6.0            manual   rear_wheel_drive
# 2         166.0               4.0         automatic    all_wheel_drive
# 3         240.0               6.0         automatic    all_wheel_drive
# 4         272.0               4.0         automatic    all_wheel_drive
# ...         ...               ...               ...                ...
# 7145      261.0               6.0         automatic   rear_wheel_drive
# 7146      550.0              12.0            manual    all_wheel_drive
# 7147      146.0               4.0         automatic    all_wheel_drive
# 7148      355.0               8.0         automatic   four_wheel_drive
# 7149      295.0               8.0         automatic   rear_wheel_drive
#
#       number_of_doors                        market_category vehicle_size  \
# 0                 4.0                                    NaN      midsize
# 1                 2.0  factory_tuner,luxury,high-performance      compact
# 2                 4.0                              crossover      midsize
# 3                 4.0                crossover,luxury,diesel        large
# 4                 2.0                     luxury,performance      compact
# ...               ...                                    ...          ...
# 7145              4.0                                    NaN      compact
# 7146              2.0                exotic,high-performance      compact
# 7147              4.0                              crossover      compact
# 7148              4.0                              flex_fuel        large
# 7149              4.0                              flex_fuel        large
#
#         vehicle_style  highway_mpg  city_mpg  popularity  door_num_2  \
# 0               sedan           24        15        1851           0
# 1         convertible           22        15        3916           1
# 2             4dr_suv           31        25         436           0
# 3             4dr_suv           28        19        3105           0
# 4               coupe           29        20        1624           1
# ...               ...          ...       ...         ...         ...
# 7145  crew_cab_pickup           20        15         481           0
# 7146            coupe           12         9        1158           1
# 7147          4dr_suv           32        27         586           0
# 7148          4dr_suv           22        15         549           0
# 7149  crew_cab_pickup           19        14         549           0
#
#       door_num_3  door_num_4
# 0              0           1
# 1              0           0
# 2              0           1
# 3              0           1
# 4              0           0
# ...          ...         ...
# 7145           0           1
# 7146           0           0
# 7147           0           1
# 7148           0           1
# 7149           0           1
#
# [7150 rows x 18 columns]

# %%
X_train
# Out:
# array([[150.,   6.,  24., ...,   0.,   0.,   1.],
#        [330.,   6.,  22., ...,   0.,   0.,   0.],
#        [166.,   4.,  31., ...,   0.,   0.,   0.],
#        ...,
#        [146.,   4.,  32., ...,   0.,   0.,   0.],
#        [355.,   8.,  22., ...,   0.,   0.,   0.],
#        [295.,   8.,  19., ...,   0.,   0.,   0.]], shape=(7150, 14))
