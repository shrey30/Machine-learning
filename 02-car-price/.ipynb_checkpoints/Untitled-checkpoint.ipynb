# %%
import numpy as np
import pandas as pd

# %%
data = 'https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/chapter-02-car-price/data.csv'

# %%
# !wget $data
# Out:
# --2026-06-11 06:55:11--  https://github.com/alexeygrigorev/mlbookcamp-code/blob/master/chapter-02-car-price/data.csv
# Resolving github.com (github.com)... 20.207.73.82
# Connecting to github.com (github.com)|20.207.73.82|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘data.csv.2’
#
# data.csv.2              [ <=>                ] 227.42K  --.-KB/s    in 0.01s
#
# 2026-06-11 06:55:12 (15.6 MB/s) - ‘data.csv.2’ saved [232877]

# %%
df = pd.read_csv('data.csv')

# %%
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
# 2                Luxury,High-Performance      Compact         Coupe
# 3                     Luxury,Performance      Compact         Coupe
# 4                                 Luxury      Compact   Convertible
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350
# 3           28        18        3916  29450
# 4           28        18        3916  34500

# %%
df['Transmission Type']
# Out:
# 0           MANUAL
# 1           MANUAL
# 2           MANUAL
# 3           MANUAL
# 4           MANUAL
#            ...
# 11909    AUTOMATIC
# 11910    AUTOMATIC
# 11911    AUTOMATIC
# 11912    AUTOMATIC
# 11913    AUTOMATIC
# Name: Transmission Type, Length: 11914, dtype: str

# %%
df.count()
# Out:
# Make                 11914
# Model                11914
# Year                 11914
# Engine Fuel Type     11911
# Engine HP            11845
# Engine Cylinders     11884
# Transmission Type    11914
# Driven_Wheels        11914
# Number of Doors      11908
# Market Category       8172
# Vehicle Size         11914
# Vehicle Style        11914
# highway MPG          11914
# city mpg             11914
# Popularity           11914
# MSRP                 11914
# dtype: int64

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')

# %%
df.columns
# Out:
# Index(['make', 'model', 'year', 'engine_fuel_type', 'engine_hp',
#        'engine_cylinders', 'transmission_type', 'driven_wheels',
#        'number_of_doors', 'market_category', 'vehicle_size', 'vehicle_style',
#        'highway_mpg', 'city_mpg', 'popularity', 'msrp'],
#       dtype='str')

# %%
df.columns.values
# Out:
# <StringArray>
# [             'make',             'model',              'year',
#   'engine_fuel_type',         'engine_hp',  'engine_cylinders',
#  'transmission_type',     'driven_wheels',   'number_of_doors',
#    'market_category',      'vehicle_size',     'vehicle_style',
#        'highway_mpg',          'city_mpg',        'popularity',
#               'msrp']
# Length: 16, dtype: str

# %%
df.head()
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          market_category vehicle_size vehicle_style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
# 2                Luxury,High-Performance      Compact         Coupe
# 3                     Luxury,Performance      Compact         Coupe
# 4                                 Luxury      Compact   Convertible
#
#    highway_mpg  city_mpg  popularity   msrp
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350
# 3           28        18        3916  29450
# 4           28        18        3916  34500

# %%
strings = df.dtypes[df.dtypes == 'str'].index
strings
# Out:
# Index(['make', 'model', 'engine_fuel_type', 'transmission_type',
#        'driven_wheels', 'market_category', 'vehicle_size', 'vehicle_style'],
#       dtype='str')

# %%
for col in strings:
    df[col] = df[col].str.lower().str.replace(' ', '_')

# %%
df.head()
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  bmw  1_series_m  2011  premium_unleaded_(required)      335.0
# 1  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 2  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 3  bmw    1_series  2011  premium_unleaded_(required)      230.0
# 4  bmw    1_series  2011  premium_unleaded_(required)      230.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            manual  rear_wheel_drive              2.0
# 1               6.0            manual  rear_wheel_drive              2.0
# 2               6.0            manual  rear_wheel_drive              2.0
# 3               6.0            manual  rear_wheel_drive              2.0
# 4               6.0            manual  rear_wheel_drive              2.0
#
#                          market_category vehicle_size vehicle_style  \
# 0  factory_tuner,luxury,high-performance      compact         coupe
# 1                     luxury,performance      compact   convertible
# 2                luxury,high-performance      compact         coupe
# 3                     luxury,performance      compact         coupe
# 4                                 luxury      compact   convertible
#
#    highway_mpg  city_mpg  popularity   msrp
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350
# 3           28        18        3916  29450
# 4           28        18        3916  34500

# %%
for col in df.columns:
    print(col)
    print(df[col].unique()[:5])
    print(df[col].nunique())
    print()
# Out:
# make
# <StringArray>
# ['bmw', 'audi', 'fiat', 'mercedes-benz', 'chrysler']
# Length: 5, dtype: str
# 48
#
# model
# <StringArray>
# ['1_series_m', '1_series', '100', '124_spider', '190-class']
# Length: 5, dtype: str
# 914
#
# year
# [2011 2012 2013 1992 1993]
# 28
#
# engine_fuel_type
# <StringArray>
# [   'premium_unleaded_(required)',               'regular_unleaded',
#  'premium_unleaded_(recommended)',       'flex-fuel_(unleaded/e85)',
#                          'diesel']
# Length: 5, dtype: str
# 10
#
# engine_hp
# [335. 300. 230. 320. 172.]
# 356
#
# engine_cylinders
# [ 6.  4.  5.  8. 12.]
# 9
#
# transmission_type
# <StringArray>
# ['manual', 'automatic', 'automated_manual', 'direct_drive', 'unknown']
# Length: 5, dtype: str
# 5
#
# driven_wheels
# <StringArray>
# ['rear_wheel_drive', 'front_wheel_drive', 'all_wheel_drive',
#  'four_wheel_drive']
# Length: 4, dtype: str
# 4
#
# number_of_doors
# [ 2.  4.  3. nan]
# 3
#
# market_category
# <StringArray>
# ['factory_tuner,luxury,high-performance',
#                     'luxury,performance',
#                'luxury,high-performance',
#                                 'luxury',
#                            'performance']
# Length: 5, dtype: str
# 71
#
# vehicle_size
# <StringArray>
# ['compact', 'midsize', 'large']
# Length: 3, dtype: str
# 3
#
# vehicle_style
# <StringArray>
# ['coupe', 'convertible', 'sedan', 'wagon', '4dr_hatchback']
# Length: 5, dtype: str
# 16
#
# highway_mpg
# [26 28 27 25 24]
# 59
#
# city_mpg
# [19 20 18 17 16]
# 69
#
# popularity
# [3916 3105  819  617 1013]
# 48
#
# msrp
# [46135 40650 36350 29450 34500]
# 6049

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
sns.histplot(df.msrp[df.msrp < 100000], bins = 50)
# Out:
# <Axes: xlabel='msrp', ylabel='Count'>

# %%
df.head()
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  bmw  1_series_m  2011  premium_unleaded_(required)      335.0
# 1  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 2  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 3  bmw    1_series  2011  premium_unleaded_(required)      230.0
# 4  bmw    1_series  2011  premium_unleaded_(required)      230.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            manual  rear_wheel_drive              2.0
# 1               6.0            manual  rear_wheel_drive              2.0
# 2               6.0            manual  rear_wheel_drive              2.0
# 3               6.0            manual  rear_wheel_drive              2.0
# 4               6.0            manual  rear_wheel_drive              2.0
#
#                          market_category vehicle_size vehicle_style  \
# 0  factory_tuner,luxury,high-performance      compact         coupe
# 1                     luxury,performance      compact   convertible
# 2                luxury,high-performance      compact         coupe
# 3                     luxury,performance      compact         coupe
# 4                                 luxury      compact   convertible
#
#    highway_mpg  city_mpg  popularity   msrp
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350
# 3           28        18        3916  29450
# 4           28        18        3916  34500

# %%
n = int(len(df))
n_val = int(n * 0.2)
n_test = int(n * 0.2)
n_train = n - n_val - n_test

# %%
n_val, n_test, n_train
# Out:
# (2382, 2382, 7150)

# %%
n
# Out:
# 11914

# %%
idx = np.arange(n)

# %%
np.random.shuffle(idx)

# %%
idx
# Out:
# array([1624, 3594, 4132, ...,  573, 2988, 3952], shape=(11914,))

# %%
df_val = df.iloc[idx[:n_val]]
df_test = df.iloc[idx[n_val:n_val+n_test]]
df_train = df.iloc[idx[n_val+n_test:]]

# %%
df_train
# Out:
#             make        model  year                engine_fuel_type  \
# 2585       honda        civic  2016                regular_unleaded
# 9383         gmc  sierra_1500  2017                regular_unleaded
# 4656     ferrari         f430  2009     premium_unleaded_(required)
# 7441       buick  park_avenue  2005     premium_unleaded_(required)
# 9333         gmc  sierra_1500  2015        flex-fuel_(unleaded/e85)
# ...          ...          ...   ...                             ...
# 10568    lincoln     town_car  2009        flex-fuel_(unleaded/e85)
# 3348       mazda         cx-3  2017                regular_unleaded
# 573         fiat         500l  2015  premium_unleaded_(recommended)
# 2988   chevrolet     corvette  2016  premium_unleaded_(recommended)
# 3952       buick       encore  2016                regular_unleaded
#
#        engine_hp  engine_cylinders transmission_type      driven_wheels  \
# 2585       158.0               4.0         automatic  front_wheel_drive
# 9383       355.0               8.0         automatic   rear_wheel_drive
# 4656       483.0               8.0  automated_manual   rear_wheel_drive
# 7441       240.0               6.0         automatic  front_wheel_drive
# 9333       285.0               6.0         automatic   rear_wheel_drive
# ...          ...               ...               ...                ...
# 10568      239.0               8.0         automatic   rear_wheel_drive
# 3348       146.0               4.0         automatic    all_wheel_drive
# 573        160.0               4.0            manual  front_wheel_drive
# 2988       460.0               8.0            manual   rear_wheel_drive
# 3952       138.0               4.0         automatic    all_wheel_drive
#
#        number_of_doors          market_category vehicle_size  \
# 2585               2.0                      NaN      compact
# 9383               4.0                      NaN        large
# 4656               2.0  exotic,high-performance      compact
# 7441               4.0              performance        large
# 9333               2.0                flex_fuel        large
# ...                ...                      ...          ...
# 10568              4.0         flex_fuel,luxury        large
# 3348               4.0                crossover      compact
# 573                4.0                      NaN      compact
# 2988               2.0         high-performance      compact
# 3952               4.0                crossover      compact
#
#             vehicle_style  highway_mpg  city_mpg  popularity    msrp
# 2585                coupe           41        30        2202   19850
# 9383      crew_cab_pickup           23        16         549   44540
# 4656                coupe           16        11        2774  200054
# 7441                sedan           26        17         155   40730
# 9333   regular_cab_pickup           24        18         549   33595
# ...                   ...          ...       ...         ...     ...
# 10568               sedan           24        16          61   46385
# 3348              4dr_suv           32        27         586   23210
# 573                 wagon           33        25         819   21695
# 2988                coupe           29        17        1385   70145
# 3952              4dr_suv           30        23         155   27855
#
# [7150 rows x 16 columns]

# %%
len(df_train), len(df_val), len(df_test)
# Out:
# (7150, 2382, 2382)

# %%
df_train
# Out:
#             make        model  year                engine_fuel_type  \
# 2585       honda        civic  2016                regular_unleaded
# 9383         gmc  sierra_1500  2017                regular_unleaded
# 4656     ferrari         f430  2009     premium_unleaded_(required)
# 7441       buick  park_avenue  2005     premium_unleaded_(required)
# 9333         gmc  sierra_1500  2015        flex-fuel_(unleaded/e85)
# ...          ...          ...   ...                             ...
# 10568    lincoln     town_car  2009        flex-fuel_(unleaded/e85)
# 3348       mazda         cx-3  2017                regular_unleaded
# 573         fiat         500l  2015  premium_unleaded_(recommended)
# 2988   chevrolet     corvette  2016  premium_unleaded_(recommended)
# 3952       buick       encore  2016                regular_unleaded
#
#        engine_hp  engine_cylinders transmission_type      driven_wheels  \
# 2585       158.0               4.0         automatic  front_wheel_drive
# 9383       355.0               8.0         automatic   rear_wheel_drive
# 4656       483.0               8.0  automated_manual   rear_wheel_drive
# 7441       240.0               6.0         automatic  front_wheel_drive
# 9333       285.0               6.0         automatic   rear_wheel_drive
# ...          ...               ...               ...                ...
# 10568      239.0               8.0         automatic   rear_wheel_drive
# 3348       146.0               4.0         automatic    all_wheel_drive
# 573        160.0               4.0            manual  front_wheel_drive
# 2988       460.0               8.0            manual   rear_wheel_drive
# 3952       138.0               4.0         automatic    all_wheel_drive
#
#        number_of_doors          market_category vehicle_size  \
# 2585               2.0                      NaN      compact
# 9383               4.0                      NaN        large
# 4656               2.0  exotic,high-performance      compact
# 7441               4.0              performance        large
# 9333               2.0                flex_fuel        large
# ...                ...                      ...          ...
# 10568              4.0         flex_fuel,luxury        large
# 3348               4.0                crossover      compact
# 573                4.0                      NaN      compact
# 2988               2.0         high-performance      compact
# 3952               4.0                crossover      compact
#
#             vehicle_style  highway_mpg  city_mpg  popularity    msrp
# 2585                coupe           41        30        2202   19850
# 9383      crew_cab_pickup           23        16         549   44540
# 4656                coupe           16        11        2774  200054
# 7441                sedan           26        17         155   40730
# 9333   regular_cab_pickup           24        18         549   33595
# ...                   ...          ...       ...         ...     ...
# 10568               sedan           24        16          61   46385
# 3348              4dr_suv           32        27         586   23210
# 573                 wagon           33        25         819   21695
# 2988                coupe           29        17        1385   70145
# 3952              4dr_suv           30        23         155   27855
#
# [7150 rows x 16 columns]

# %%
df_train = df_train.reset_index(drop = True)
df_val = df_val.reset_index(drop = True)
df_test = df_test.reset_index(drop = True)

# %%
df_train
# Out:
#            make        model  year                engine_fuel_type  engine_hp  \
# 0         honda        civic  2016                regular_unleaded      158.0
# 1           gmc  sierra_1500  2017                regular_unleaded      355.0
# 2       ferrari         f430  2009     premium_unleaded_(required)      483.0
# 3         buick  park_avenue  2005     premium_unleaded_(required)      240.0
# 4           gmc  sierra_1500  2015        flex-fuel_(unleaded/e85)      285.0
# ...         ...          ...   ...                             ...        ...
# 7145    lincoln     town_car  2009        flex-fuel_(unleaded/e85)      239.0
# 7146      mazda         cx-3  2017                regular_unleaded      146.0
# 7147       fiat         500l  2015  premium_unleaded_(recommended)      160.0
# 7148  chevrolet     corvette  2016  premium_unleaded_(recommended)      460.0
# 7149      buick       encore  2016                regular_unleaded      138.0
#
#       engine_cylinders transmission_type      driven_wheels  number_of_doors  \
# 0                  4.0         automatic  front_wheel_drive              2.0
# 1                  8.0         automatic   rear_wheel_drive              4.0
# 2                  8.0  automated_manual   rear_wheel_drive              2.0
# 3                  6.0         automatic  front_wheel_drive              4.0
# 4                  6.0         automatic   rear_wheel_drive              2.0
# ...                ...               ...                ...              ...
# 7145               8.0         automatic   rear_wheel_drive              4.0
# 7146               4.0         automatic    all_wheel_drive              4.0
# 7147               4.0            manual  front_wheel_drive              4.0
# 7148               8.0            manual   rear_wheel_drive              2.0
# 7149               4.0         automatic    all_wheel_drive              4.0
#
#               market_category vehicle_size       vehicle_style  highway_mpg  \
# 0                         NaN      compact               coupe           41
# 1                         NaN        large     crew_cab_pickup           23
# 2     exotic,high-performance      compact               coupe           16
# 3                 performance        large               sedan           26
# 4                   flex_fuel        large  regular_cab_pickup           24
# ...                       ...          ...                 ...          ...
# 7145         flex_fuel,luxury        large               sedan           24
# 7146                crossover      compact             4dr_suv           32
# 7147                      NaN      compact               wagon           33
# 7148         high-performance      compact               coupe           29
# 7149                crossover      compact             4dr_suv           30
#
#       city_mpg  popularity    msrp
# 0           30        2202   19850
# 1           16         549   44540
# 2           11        2774  200054
# 3           17         155   40730
# 4           18         549   33595
# ...        ...         ...     ...
# 7145        16          61   46385
# 7146        27         586   23210
# 7147        25         819   21695
# 7148        17        1385   70145
# 7149        23         155   27855
#
# [7150 rows x 16 columns]

# %%
y_train = np.log1p(df_train.msrp.values)
y_val = np.log1p(df_val.msrp.values)
y_test = np.log1p(df_test.msrp.values)

# %%
y_train
# Out:
# array([ 9.89600966, 10.70416539, 12.20634761, ...,  9.98488319,
#        11.15833406, 10.23480366], shape=(7150,))

# %%
del df_train['msrp']

# %%
del df_val['msrp']
del df_test['msrp']

# %%
df_train
# Out:
#            make        model  year                engine_fuel_type  engine_hp  \
# 0         honda        civic  2016                regular_unleaded      158.0
# 1           gmc  sierra_1500  2017                regular_unleaded      355.0
# 2       ferrari         f430  2009     premium_unleaded_(required)      483.0
# 3         buick  park_avenue  2005     premium_unleaded_(required)      240.0
# 4           gmc  sierra_1500  2015        flex-fuel_(unleaded/e85)      285.0
# ...         ...          ...   ...                             ...        ...
# 7145    lincoln     town_car  2009        flex-fuel_(unleaded/e85)      239.0
# 7146      mazda         cx-3  2017                regular_unleaded      146.0
# 7147       fiat         500l  2015  premium_unleaded_(recommended)      160.0
# 7148  chevrolet     corvette  2016  premium_unleaded_(recommended)      460.0
# 7149      buick       encore  2016                regular_unleaded      138.0
#
#       engine_cylinders transmission_type      driven_wheels  number_of_doors  \
# 0                  4.0         automatic  front_wheel_drive              2.0
# 1                  8.0         automatic   rear_wheel_drive              4.0
# 2                  8.0  automated_manual   rear_wheel_drive              2.0
# 3                  6.0         automatic  front_wheel_drive              4.0
# 4                  6.0         automatic   rear_wheel_drive              2.0
# ...                ...               ...                ...              ...
# 7145               8.0         automatic   rear_wheel_drive              4.0
# 7146               4.0         automatic    all_wheel_drive              4.0
# 7147               4.0            manual  front_wheel_drive              4.0
# 7148               8.0            manual   rear_wheel_drive              2.0
# 7149               4.0         automatic    all_wheel_drive              4.0
#
#               market_category vehicle_size       vehicle_style  highway_mpg  \
# 0                         NaN      compact               coupe           41
# 1                         NaN        large     crew_cab_pickup           23
# 2     exotic,high-performance      compact               coupe           16
# 3                 performance        large               sedan           26
# 4                   flex_fuel        large  regular_cab_pickup           24
# ...                       ...          ...                 ...          ...
# 7145         flex_fuel,luxury        large               sedan           24
# 7146                crossover      compact             4dr_suv           32
# 7147                      NaN      compact               wagon           33
# 7148         high-performance      compact               coupe           29
# 7149                crossover      compact             4dr_suv           30
#
#       city_mpg  popularity
# 0           30        2202
# 1           16         549
# 2           11        2774
# 3           17         155
# 4           18         549
# ...        ...         ...
# 7145        16          61
# 7146        27         586
# 7147        25         819
# 7148        17        1385
# 7149        23         155
#
# [7150 rows x 15 columns]

# %%
df_train.dtypes
# Out:
# make                     str
# model                    str
# year                   int64
# engine_fuel_type         str
# engine_hp            float64
# engine_cylinders     float64
# transmission_type        str
# driven_wheels            str
# number_of_doors      float64
# market_category          str
# vehicle_size             str
# vehicle_style            str
# highway_mpg            int64
# city_mpg               int64
# popularity             int64
# dtype: object

# %%
base = ['engine_hp', 'engine_cylinders', 'highway_mpg', 'city_mpg', 'popularity']

# %%
base
# Out:
# ['engine_hp', 'engine_cylinders', 'highway_mpg', 'city_mpg', 'popularity']

# %%
df_train[base]
# Out:
#       engine_hp  engine_cylinders  highway_mpg  city_mpg  popularity
# 0         158.0               4.0           41        30        2202
# 1         355.0               8.0           23        16         549
# 2         483.0               8.0           16        11        2774
# 3         240.0               6.0           26        17         155
# 4         285.0               6.0           24        18         549
# ...         ...               ...          ...       ...         ...
# 7145      239.0               8.0           24        16          61
# 7146      146.0               4.0           32        27         586
# 7147      160.0               4.0           33        25         819
# 7148      460.0               8.0           29        17        1385
# 7149      138.0               4.0           30        23         155
#
# [7150 rows x 5 columns]

# %%
X_train = df_train[base].values

# %%
X_train
# Out:
# array([[ 158.,    4.,   41.,   30., 2202.],
#        [ 355.,    8.,   23.,   16.,  549.],
#        [ 483.,    8.,   16.,   11., 2774.],
#        ...,
#        [ 160.,    4.,   33.,   25.,  819.],
#        [ 460.,    8.,   29.,   17., 1385.],
#        [ 138.,    4.,   30.,   23.,  155.]], shape=(7150, 5))

# %%
y_train
# Out:
# array([ 9.89600966, 10.70416539, 12.20634761, ...,  9.98488319,
#        11.15833406, 10.23480366], shape=(7150,))

# %%
def train_linear_regression(X, y):
    ones = np.ones(X.shape[0])
    X = np.column_stack([ones, X])
    XTX = X.T.dot(X)
    XTX_inv = np.linalg.inv(XTX)
    w_full = XTX_inv.dot(X.T).dot(y)

    return w_full[0], w_full[1:]

# %%
df_train[base].isnull().sum()
# Out:
# engine_hp           37
# engine_cylinders    17
# highway_mpg          0
# city_mpg             0
# popularity           0
# dtype: int64

# %%
X_train = df_train[base].fillna(0).values

# %%
X_train
# Out:
# array([[ 158.,    4.,   41.,   30., 2202.],
#        [ 355.,    8.,   23.,   16.,  549.],
#        [ 483.,    8.,   16.,   11., 2774.],
#        ...,
#        [ 160.,    4.,   33.,   25.,  819.],
#        [ 460.,    8.,   29.,   17., 1385.],
#        [ 138.,    4.,   30.,   23.,  155.]], shape=(7150, 5))

# %%
w0, w = train_linear_regression(X_train, y_train)

# %%
w0
# Out:
# np.float64(7.857574663752842)

# %%
w
# Out:
# array([ 9.45358315e-03, -1.40175954e-01,  1.58858049e-02,  1.51242776e-02,
#        -1.34917412e-05])

# %%
y_pred = w0 + X_train.dot(w)

# %%
sns.histplot(y_pred, color='red', bins = 50, alpha = 0.5)
sns.histplot(y_train, color='blue', bins = 50, alpha = 0.5)
# Out:
# <Axes: ylabel='Count'>

# %%
def rmse(y, y_pred):
    error = (y - y_pred)
    se = error ** 2
    mse = se.mean()
    return np.sqrt(mse)

# %%
rmse(y_train, y_pred)
# Out:
# np.float64(0.7530134837711382)
